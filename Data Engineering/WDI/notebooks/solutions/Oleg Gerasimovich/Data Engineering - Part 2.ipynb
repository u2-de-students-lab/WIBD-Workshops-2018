# %% [markdown]
# # Data Transformation, Modeling and Quality

# %% [markdown]
# In this notebook we'll look at how to transform the input datasets to be consumed into a Data Model.

# %% [markdown]
# ### Step 1 - What inputs do you have?

# %%
# %%bash
# ls ../data
# Out:
# WDICountry.csv
# WDIData.csv
# WDISeries.csv

# %% [markdown]
# ### Step 2 - Get your tools setup

# %% [markdown]
# As part of this we will be using [PySpark](http://spark.apache.org/docs/2.1.1/api/python/index.html) to inspect the data on hand and also gather some basic details.

# %%
import os
from IPython.display import display, HTML
import pandas as pd

#Locating where pyspark is installed
import findspark
findspark.init()
import pyspark

#Settings for PySpark to work
driver_memory = '4g'
num_executors = 2
executor_memory = '1g'
#pyspark_submit_args = ' --driver-memory ' + driver_memory + ' --executor-memory ' + executor_memory + ' --num-executors ' + num_executors + ' pyspark-shell'
pyspark_submit_args = ' --driver-memory ' + driver_memory + ' pyspark-shell'

#Setting the required parameters to start up PySpark
os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args

#Import Modules Needed for PySpark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
#Helper for pretty formatting for Spark DataFrames
def showDF(df, limitRows =  20, truncate = True):
    if(truncate):
        pd.set_option('display.max_colwidth', 50)
    else:
        pd.set_option('display.max_colwidth', -1)
    pd.set_option('display.max_rows', limitRows)
    display(df.limit(limitRows).toPandas())
    pd.reset_option('display.max_rows')

# %%
#Creating a spark session
spark = SparkSession.builder.appName("Data Transformation").getOrCreate()
# Out:
# 22/01/28 20:16:38 WARN Utils: Your hostname, wsc-043-72a resolves to a loopback address: 127.0.1.1; using 192.168.34.43 instead (on interface enp2s0)
# 22/01/28 20:16:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/01/28 20:16:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/01/28 20:16:40 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# ### Step 3 - Read the data
#
# We will be using the WDICountry, WDISeries and WDIData files for all the activity below.

# %%
#Read the file into a Spark Data Frame
country = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("../data/WDICountry.csv")

country.count()
# Out:
# 263

# %%
series = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("../data/WDISeries.csv")

series.count()
# Out:
# 1593

# %%
indicators = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("../data/WDIData.csv")

indicators.count()
# Out:
# 420024

# %% [markdown]
# ### Step 4 - Transform the data

# %% [markdown]
# #### Transform the Country Dataset
# - Select the columns that we will need for our data model
# - Rename columns for data ingestion
#
# We'll be using the various operations supported for a DataFrame.  You can view the complete list [here](http://spark.apache.org/docs/2.1.1/api/python/pyspark.sql.html#pyspark.sql.DataFrame) .

# %%
countryDim = country \
    .select("2-alpha code", "Country Code", "Short Name", "Long Name", "Region", "Income Group") \
    .withColumnRenamed("2-alpha code", "country_iso_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .withColumnRenamed("Short Name", "country_name") \
    .withColumnRenamed("Long Name", "country_long_name") \
    .withColumnRenamed("Region", "region") \
    .withColumnRenamed("Income Group", "income_group")
    
showDF(countryDim)
# Out:
#    country_iso_code wb_country_code          country_name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                   country_long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %% [markdown]
# #### You can also do the similar transformations in sql
# Let's rename the country_name and country_long_name columns

# %%
#Lets you create a view that you can use in SQL queries
countryDim.createOrReplaceTempView("country")
# Out:
# 22/01/28 16:49:41 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
transformQuery = """
select 
    country_iso_code
    , wb_country_code
    , country_name as name
    , country_long_name as long_name
    , region
    , income_group
from 
    country
"""

showDF(spark.sql(transformQuery))
# Out:
#    country_iso_code wb_country_code                  name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                           long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %% [markdown]
# ### Step 5 - Check the data quality

# %% [markdown]
# ##### Do all countries have 2 character country_iso_codes ?
#
# We will use some sql functions supported in PySpark for this exercise.  You can find a complete list of functions supported [here](http://spark.apache.org/docs/2.1.1/api/python/pyspark.sql.html#module-pyspark.sql.functions) .

# %%
showDF( \
    countryDim \
       .select(col("country_iso_code"), \
               length(col("country_iso_code")).alias("column_length")) \
       .groupBy("column_length") \
       .agg(count("*").alias("cnt")) \
       .filter("cnt > 1") \
)
# Out:
#    column_length  cnt
# 0              2  262

# %%
#You can also do this in SQL
countryCodeLengthQuery = """
select 
    length(country_iso_code) as column_length
    , count(1) as cnt
from 
    country
group by 
    length(country_iso_code)
having 
    count(1) > 1
"""

showDF(spark.sql(countryCodeLengthQuery))
# Out:
#    column_length  cnt
# 0              2  262

# %% [markdown]
# ## Quick Exercise
# Do you notice a difference in the counts returned by the Quality check for the 2-character country_iso_code vs the original row count for the WDICountry.csv ?

# %%
# Paste your solution here
# Original count - 263, quality count - 262

# %% [markdown]
# ##### Do we have duplicate records for any of the key columns ?

# %%
showDF(countryDim.groupBy("country_iso_code").agg(count("*").alias("cnt")).filter("cnt > 1"))

showDF(countryDim.groupBy("wb_country_code").agg(count("*").alias("cnt")).filter("cnt > 1"))

showDF(countryDim.groupBy("country_name").agg(count("*").alias("cnt")).filter("cnt > 1"))
# Out:
# Empty DataFrame
# Columns: [country_iso_code, cnt]
# Index: []
# Empty DataFrame
# Columns: [wb_country_code, cnt]
# Index: []
# Empty DataFrame
# Columns: [country_name, cnt]
# Index: []

# %% [markdown]
# ### Step 6 - Fix any issues with data quality

# %%
countryDimFinal = countryDim.filter("country_iso_code is not null")

showDF(countryDimFinal)
# Out:
#    country_iso_code wb_country_code          country_name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                   country_long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %%
countryDimFinal.count()
# Out:
# 262

# %% [markdown]
# ### Step 7 - Write the data to the destination

# %%
# Here we are going to write the country dimension to an output csv file
countryDimFinal \
    .coalesce(1) \
    .write.csv('../output/CountryDim', mode='overwrite', header='true')

# %% [markdown]
# ### Step 8 - Check if the output was written out as expected

# %%
# %%bash
# cat ../output/CountryDim/*csv | head
# Out:
# country_iso_code,wb_country_code,country_name,country_long_name,region,income_group
# AW,ABW,Aruba,Aruba,Latin America & Caribbean,High income
# AF,AFG,Afghanistan,Islamic State of Afghanistan,South Asia,Low income
# AO,AGO,Angola,People's Republic of Angola,Sub-Saharan Africa,Lower middle income
# AL,ALB,Albania,Republic of Albania,Europe & Central Asia,Upper middle income
# AD,AND,Andorra,Principality of Andorra,Europe & Central Asia,High income
# 1A,ARB,Arab World,Arab World,"",""
# AE,ARE,United Arab Emirates,United Arab Emirates,Middle East & North Africa,High income
# AR,ARG,Argentina,Argentine Republic,"",""
# AM,ARM,Armenia,Republic of Armenia,Europe & Central Asia,Lower middle income

# %% [markdown]
# ## Exercise
#
# #### Transform the Series Dataset and make it available in the dataframe seriesDim
# - Filter only for series that have Annual periodicity
# - Get the following columns and rename the selected columns to prepare further processing
#
# | Name in CSV | Column Name |
# | ------------- |:-------------:|
# | Series Code | indicator_code |
# | Indicator Name | indicator_name |
# | Periodicity | periodicity |
# | Aggregation Method | aggregation_method |
#
#
# ##### How many series do you end up with ?

# %%
#Your solution here
#seriesDim = ??? 
seriesDim = series \
            .select('Series Code', 'Indicator Name', 'Periodicity', 'Aggregation Method') \
            .withColumnRenamed('Series Code', 'indicator_code') \
            .withColumnRenamed('Indicator Name', 'indicator_name') \
            .withColumnRenamed('Periodicity', 'periodicity') \
            .withColumnRenamed('Aggregation Method', 'aggregation_method') 

showDF(seriesDim)

seriesDim.count()
# Out:
#        indicator_code                                     indicator_name  \
# 0      AG.AGR.TRAC.NO                   Agricultural machinery, tractors
# 1   AG.CON.FERT.PT.ZS  Fertilizer consumption (% of fertilizer produc...
# 2      AG.CON.FERT.ZS  Fertilizer consumption (kilograms per hectare ...
# 3      AG.LND.AGRI.K2                         Agricultural land (sq. km)
# 4      AG.LND.AGRI.ZS                 Agricultural land (% of land area)
# 5      AG.LND.ARBL.HA                             Arable land (hectares)
# 6   AG.LND.ARBL.HA.PC                  Arable land (hectares per person)
# 7      AG.LND.ARBL.ZS                       Arable land (% of land area)
# 8      AG.LND.CREL.HA            Land under cereal production (hectares)
# 9      AG.LND.CROP.ZS                Permanent cropland (% of land area)
# 10  AG.LND.EL5M.RU.K2  Rural land area where elevation is below 5 met...
# 11  AG.LND.EL5M.RU.ZS  Rural land area where elevation is below 5 met...
# 12  AG.LND.EL5M.UR.K2  Urban land area where elevation is below 5 met...
# 13  AG.LND.EL5M.UR.ZS  Urban land area where elevation is below 5 met...
# 14     AG.LND.EL5M.ZS  Land area where elevation is below 5 meters (%...
# 15     AG.LND.FRST.K2                               Forest area (sq. km)
# 16     AG.LND.FRST.ZS                       Forest area (% of land area)
# 17  AG.LND.IRIG.AG.ZS  Agricultural irrigated land (% of total agricu...
# 18     AG.LND.PRCP.MM       Average precipitation in depth (mm per year)
# 19     AG.LND.TOTL.K2                                 Land area (sq. km)
#
#    periodicity aggregation_method
# 0       Annual                Sum
# 1       Annual   Weighted average
# 2       Annual   Weighted average
# 3       Annual                Sum
# 4       Annual   Weighted average
# 5       Annual               None
# 6       Annual   Weighted Average
# 7       Annual   Weighted average
# 8       Annual                Sum
# 9       Annual   Weighted average
# 10      Annual                Sum
# 11      Annual   Weighted Average
# 12      Annual                Sum
# 13      Annual   Weighted Average
# 14      Annual   Weighted Average
# 15      Annual                Sum
# 16      Annual   Weighted average
# 17      Annual   Weighted average
# 18      Annual               None
# 19      Annual                Sum
# 1593

# %% [markdown]
# #### What data quality checks were you able to perform ?

# %% [markdown]
# - Are there any duplicate codes ?
# - Are all indicator_codes following the same pattern ?
# - Is the case on columns consistent ?

# %%
#Your solution here
showDF( \
    seriesDim \
       .filter(col('indicator_code').like('%.%.%.%'))
       .select(col("indicator_code")) \
       .agg(count("*").alias("cnt")) \
)

seriesDim.select('indicator_code').distinct().count()
# Out:
#     cnt
# 0  1425
# 1592

# %% [markdown]
# ### Complex Transformations
# ##### Problem Statement
# We want to measure the cellular and broadband penetration in comparison to the population demographics for every country.  It'll also be helpful to get some insights on annual global aggregates.

# %% [markdown]
# ###### Our dataset has multiple types of metrics.  The only ones that we care about are simple aggregates.

# %%
simpleAggIndicators = seriesDim \
    .filter("lower(aggregation_method) = 'sum'") \
    .select("indicator_code", "indicator_name") \
    .orderBy("indicator_code")

showDF(simpleAggIndicators, limitRows = 500, truncate = False)
# Out:
# /tmp/ipykernel_384639/4017514554.py:6: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#            indicator_code  \
# 0    AG.AGR.TRAC.NO
# 1    AG.LND.AGRI.K2
# 2    AG.LND.CREL.HA
# 3    AG.LND.EL5M.RU.K2
# 4    AG.LND.EL5M.UR.K2
# 5    AG.LND.FRST.K2
# 6    AG.LND.TOTL.K2
# 7    AG.LND.TOTL.RU.K2
# 8    AG.LND.TOTL.UR.K2
# 9    AG.PRD.CREL.MT
# 10   AG.SRF.TOTL.K2
# 11   BM.GSR.FCTY.CD
# 12   BM.GSR.ROYL.CD
# 13   BM.KLT.DINV.CD.WD
# 14   BM.TRF.PRVT.CD
# 15   BM.TRF.PWKR.CD.DT
# 16   BX.GRT.EXTA.CD.WD
# 17   BX.GRT.TECH.CD.WD
# 18   BX.GSR.CCIS.CD
# 19   BX.GSR.FCTY.CD
# 20   BX.GSR.ROYL.CD
# 21   BX.KLT.DINV.CD.WD
# 22   BX.KLT.DREM.CD.DT
# 23   BX.PEF.TOTL.CD.WD
# 24   BX.TRF.CURR.CD
# 25   BX.TRF.PWKR.CD
# 26   BX.TRF.PWKR.CD.DT
# 27   CM.MKT.LCAP.CD
# 28   CM.MKT.LDOM.NO
# 29   CM.MKT.TRAD.CD
# 30   DC.DAC.AUSL.CD
# 31   DC.DAC.AUTL.CD
# 32   DC.DAC.BELL.CD
# 33   DC.DAC.CANL.CD
# 34   DC.DAC.CECL.CD
# 35   DC.DAC.CHEL.CD
# 36   DC.DAC.CZEL.CD
# 37   DC.DAC.DEUL.CD
# 38   DC.DAC.DNKL.CD
# 39   DC.DAC.ESPL.CD
# 40   DC.DAC.FINL.CD
# 41   DC.DAC.FRAL.CD
# 42   DC.DAC.GBRL.CD
# 43   DC.DAC.GRCL.CD
# 44   DC.DAC.IRLL.CD
# 45   DC.DAC.ISLL.CD
# 46   DC.DAC.ITAL.CD
# 47   DC.DAC.JPNL.CD
# 48   DC.DAC.KORL.CD
# 49   DC.DAC.LUXL.CD
# 50   DC.DAC.NLDL.CD
# 51   DC.DAC.NORL.CD
# 52   DC.DAC.NZLL.CD
# 53   DC.DAC.POLL.CD
# 54   DC.DAC.PRTL.CD
# 55   DC.DAC.SVKL.CD
# 56   DC.DAC.SVNL.CD
# 57   DC.DAC.SWEL.CD
# 58   DC.DAC.TOTL.CD
# 59   DC.DAC.USAL.CD
# 60   DT.AMT.BLAT.CD
# 61   DT.AMT.BLTC.CD
# 62   DT.AMT.DIMF.CD
# 63   DT.AMT.DLTF.CD
# 64   DT.AMT.DLXF.CD
# 65   DT.AMT.DPNG.CD
# 66   DT.AMT.DPPG.CD
# 67   DT.AMT.MIBR.CD
# 68   DT.AMT.MIDA.CD
# 69   DT.AMT.MLAT.CD
# 70   DT.AMT.MLTC.CD
# 71   DT.AMT.OFFT.CD
# 72   DT.AMT.PBND.CD
# 73   DT.AMT.PCBK.CD
# 74   DT.AMT.PNGB.CD
# 75   DT.AMT.PNGC.CD
# 76   DT.AMT.PROP.CD
# 77   DT.AMT.PRVT.CD
# 78   DT.AXA.DPPG.CD
# 79   DT.AXA.OFFT.CD
# 80   DT.AXA.PRVT.CD
# 81   DT.AXF.DPPG.CD
# 82   DT.AXR.DPPG.CD
# 83   DT.AXR.OFFT.CD
# 84   DT.AXR.PRVT.CD
# 85   DT.COM.DPPG.CD
# 86   DT.COM.MIBR.CD
# 87   DT.COM.MIDA.CD
# 88   DT.COM.OFFT.CD
# 89   DT.COM.PRVT.CD
# 90   DT.DFR.DPPG.CD
# 91   DT.DIS.BLAT.CD
# 92   DT.DIS.BLTC.CD
# 93   DT.DIS.DIMF.CD
# 94   DT.DIS.DLTF.CD
# 95   DT.DIS.DLXF.CD
# 96   DT.DIS.DPNG.CD
# 97   DT.DIS.DPPG.CD
# 98   DT.DIS.IDAG.CD
# 99   DT.DIS.MIBR.CD
# 100  DT.DIS.MIDA.CD
# 101  DT.DIS.MLAT.CD
# 102  DT.DIS.MLTC.CD
# 103  DT.DIS.OFFT.CD
# 104  DT.DIS.PBND.CD
# 105  DT.DIS.PCBK.CD
# 106  DT.DIS.PNGB.CD
# 107  DT.DIS.PNGC.CD
# 108  DT.DIS.PROP.CD
# 109  DT.DIS.PRVT.CD
# 110  DT.DOD.ALLC.CD
# 111  DT.DOD.BLAT.CD
# 112  DT.DOD.BLTC.CD
# 113  DT.DOD.DECT.CD
# 114  DT.DOD.DECT.CD.CG
# 115  DT.DOD.DIMF.CD
# 116  DT.DOD.DLXF.CD
# 117  DT.DOD.DPNG.CD
# 118  DT.DOD.DPPG.CD
# 119  DT.DOD.DSTC.CD
# 120  DT.DOD.MDRI.CD
# 121  DT.DOD.MIBR.CD
# 122  DT.DOD.MIDA.CD
# 123  DT.DOD.MLAT.CD
# 124  DT.DOD.MLTC.CD
# 125  DT.DOD.MWBG.CD
# 126  DT.DOD.OFFT.CD
# 127  DT.DOD.PBND.CD
# 128  DT.DOD.PCBK.CD
# 129  DT.DOD.PNGB.CD
# 130  DT.DOD.PNGC.CD
# 131  DT.DOD.PROP.CD
# 132  DT.DOD.PRVS.CD
# 133  DT.DOD.PRVT.CD
# 134  DT.DOD.PUBS.CD
# 135  DT.DOD.PVLX.CD
# 136  DT.DOD.RSDL.CD
# 137  DT.DOD.VTOT.CD
# 138  DT.DSB.DPPG.CD
# 139  DT.DSF.DPPG.CD
# 140  DT.DXR.DPPG.CD
# 141  DT.INT.BLAT.CD
# 142  DT.INT.BLTC.CD
# 143  DT.INT.DECT.CD
# 144  DT.INT.DIMF.CD
# 145  DT.INT.DLXF.CD
# 146  DT.INT.DPNG.CD
# 147  DT.INT.DPPG.CD
# 148  DT.INT.DSTC.CD
# 149  DT.INT.MIBR.CD
# 150  DT.INT.MIDA.CD
# 151  DT.INT.MLAT.CD
# 152  DT.INT.MLTC.CD
# 153  DT.INT.OFFT.CD
# 154  DT.INT.PBND.CD
# 155  DT.INT.PCBK.CD
# 156  DT.INT.PNGB.CD
# 157  DT.INT.PNGC.CD
# 158  DT.INT.PROP.CD
# 159  DT.INT.PRVT.CD
# 160  DT.IXA.DPPG.CD
# 161  DT.IXA.DPPG.CD.CG
# 162  DT.IXA.OFFT.CD
# 163  DT.IXA.PRVT.CD
# 164  DT.IXF.DPPG.CD
# 165  DT.IXR.DPPG.CD
# 166  DT.IXR.OFFT.CD
# 167  DT.IXR.PRVT.CD
# 168  DT.NFL.BLAT.CD
# 169  DT.NFL.BLTC.CD
# 170  DT.NFL.BOND.CD
# 171  DT.NFL.DECT.CD
# 172  DT.NFL.DLXF.CD
# 173  DT.NFL.DPNG.CD
# 174  DT.NFL.DPPG.CD
# 175  DT.NFL.DSTC.CD
# 176  DT.NFL.FAOG.CD
# 177  DT.NFL.IAEA.CD
# 178  DT.NFL.IFAD.CD
# 179  DT.NFL.ILOG.CD
# 180  DT.NFL.IMFC.CD
# 181  DT.NFL.IMFN.CD
# 182  DT.NFL.MIBR.CD
# 183  DT.NFL.MIDA.CD
# 184  DT.NFL.MLAT.CD
# 185  DT.NFL.MLTC.CD
# 186  DT.NFL.MOTH.CD
# 187  DT.NFL.NEBR.CD
# 188  DT.NFL.NIFC.CD
# 189  DT.NFL.OFFT.CD
# 190  DT.NFL.PBND.CD
# 191  DT.NFL.PCBK.CD
# 192  DT.NFL.PCBO.CD
# 193  DT.NFL.PNGB.CD
# 194  DT.NFL.PNGC.CD
# 195  DT.NFL.PROP.CD
# 196  DT.NFL.PRVT.CD
# 197  DT.NFL.RDBC.CD
# 198  DT.NFL.RDBN.CD
# 199  DT.NFL.UNAI.CD
# 200  DT.NFL.UNCF.CD
# 201  DT.NFL.UNCR.CD
# 202  DT.NFL.UNDP.CD
# 203  DT.NFL.UNEC.CD
# 204  DT.NFL.UNFP.CD
# 205  DT.NFL.UNPB.CD
# 206  DT.NFL.UNRW.CD
# 207  DT.NFL.UNTA.CD
# 208  DT.NFL.WFPG.CD
# 209  DT.NFL.WHOL.CD
# 210  DT.NTR.BLAT.CD
# 211  DT.NTR.BLTC.CD
# 212  DT.NTR.DECT.CD
# 213  DT.NTR.DLXF.CD
# 214  DT.NTR.DPNG.CD
# 215  DT.NTR.DPPG.CD
# 216  DT.NTR.MIBR.CD
# 217  DT.NTR.MIDA.CD
# 218  DT.NTR.MLAT.CD
# 219  DT.NTR.MLTC.CD
# 220  DT.NTR.OFFT.CD
# 221  DT.NTR.PBND.CD
# 222  DT.NTR.PCBK.CD
# 223  DT.NTR.PNGB.CD
# 224  DT.NTR.PNGC.CD
# 225  DT.NTR.PROP.CD
# 226  DT.NTR.PRVT.CD
# 227  DT.ODA.ALLD.CD
# 228  DT.ODA.ALLD.KD
# 229  DT.ODA.OATL.CD
# 230  DT.ODA.OATL.KD
# 231  DT.ODA.ODAT.CD
# 232  DT.ODA.ODAT.KD
# 233  DT.TDS.BLAT.CD
# 234  DT.TDS.BLTC.CD
# 235  DT.TDS.DECT.CD
# 236  DT.TDS.DIMF.CD
# 237  DT.TDS.DLXF.CD
# 238  DT.TDS.DPNG.CD
# 239  DT.TDS.DPPG.CD
# 240  DT.TDS.MIBR.CD
# 241  DT.TDS.MIDA.CD
# 242  DT.TDS.MLAT.CD
# 243  DT.TDS.MLTC.CD
# 244  DT.TDS.OFFT.CD
# 245  DT.TDS.PBND.CD
# 246  DT.TDS.PCBK.CD
# 247  DT.TDS.PNGB.CD
# 248  DT.TDS.PNGC.CD
# 249  DT.TDS.PROP.CD
# 250  DT.TDS.PRVT.CD
# 251  DT.TXR.DPPG.CD
# 252  DT.UND.DPPG.CD
# 253  DT.UND.OFFT.CD
# 254  DT.UND.PRVT.CD
# 255  EG.ELC.RNWX.KH
# 256  EN.ATM.GHGO.KT.CE
# 257  EN.ATM.GHGT.KT.CE
# 258  EN.ATM.METH.AG.KT.CE
# 259  EN.ATM.METH.EG.KT.CE
# 260  EN.ATM.METH.KT.CE
# 261  EN.ATM.NOXE.AG.KT.CE
# 262  EN.ATM.NOXE.EG.KT.CE
# 263  EN.ATM.NOXE.KT.CE
# 264  EN.BIR.THRD.NO
# 265  EN.FSH.THRD.NO
# 266  EN.HPT.THRD.NO
# 267  EN.MAM.THRD.NO
# 268  ER.FSH.AQUA.MT
# 269  ER.FSH.CAPT.MT
# 270  ER.FSH.PROD.MT
# 271  ER.H2O.FWTL.K3
# 272  ER.H2O.INTR.K3
# 273  IE.PPI.ENGY.CD
# 274  IE.PPI.ICTI.CD
# 275  IE.PPI.TELE.CD
# 276  IE.PPI.TRAN.CD
# 277  IE.PPI.WATR.CD
# 278  IE.PPN.ENGY.CD
# 279  IE.PPN.ICTI.CD
# 280  IE.PPN.TELE.CD
# 281  IE.PPN.TRAN.CD
# 282  IE.PPN.WATR.CD
# 283  IP.IDS.NRCT
# 284  IP.IDS.RSCT
# 285  IP.PAT.NRES
# 286  IP.PAT.RESD
# 287  IP.TMK.NRCT
# 288  IP.TMK.NRES
# 289  IP.TMK.RESD
# 290  IP.TMK.RSCT
# 291  IP.TMK.TOTL
# 292  IS.AIR.DPRT
# 293  IS.AIR.GOOD.MT.K1
# 294  IS.AIR.PSGR
# 295  IS.RRS.TOTL.KM
# 296  IS.SHP.GOOD.TU
# 297  IT.CEL.SETS
# 298  IT.MLT.MAIN
# 299  IT.NET.BBND
# 300  IT.NET.SECR
# 301  MS.MIL.MPRT.KD
# 302  MS.MIL.TOTL.P1
# 303  MS.MIL.XPRT.KD
# 304  SE.PRM.ENRL
# 305  SE.PRM.TCHR
# 306  SE.PRM.UNER
# 307  SE.PRM.UNER.FE
# 308  SE.PRM.UNER.MA
# 309  SE.SEC.ENRL
# 310  SE.SEC.ENRL.GC
# 311  SE.SEC.ENRL.VO
# 312  SE.SEC.TCHR
# 313  SE.SEC.TCHR.FE
# 314  SH.DTH.0514
# 315  SH.DTH.IMRT
# 316  SH.DTH.MORT
# 317  SH.DTH.NMRT
# 318  SH.MMR.DTHS
# 319  SH.UHC.NOP1.TO
# 320  SH.UHC.NOP2.TO
# 321  SH.UHC.OOPC.10.TO
# 322  SH.UHC.OOPC.25.TO
# 323  SL.TLF.TOTL.IN
# 324  SM.POP.NETM
# 325  SM.POP.REFG
# 326  SM.POP.REFG.OR
# 327  SM.POP.TOTL
# 328  SP.POP.0014.FE.IN
# 329  SP.POP.0014.MA.IN
# 330  SP.POP.0014.TO
# 331  SP.POP.1564.FE.IN
# 332  SP.POP.1564.MA.IN
# 333  SP.POP.1564.TO
# 334  SP.POP.65UP.FE.IN
# 335  SP.POP.65UP.MA.IN
# 336  SP.POP.65UP.TO
# 337  SP.POP.TOTL
# 338  SP.POP.TOTL.FE.IN
# 339  SP.POP.TOTL.MA.IN
# 340  SP.RUR.TOTL
# 341  SP.URB.TOTL
# 342  TM.VAL.MRCH.WL.CD
# 343  TX.VAL.MRCH.WL.CD
# 344  TX.VAL.TECH.CD
# 345  VC.BTL.DETH
# 346  VC.IDP.NWCV
# 347  VC.IDP.NWDS
# 348  VC.IDP.TOCV
# 349  VC.PKP.TOTL.UN
#
#                                                                                                           indicator_name
# 0    Agricultural machinery, tractors
# 1    Agricultural land (sq. km)
# 2    Land under cereal production (hectares)
# 3    Rural land area where elevation is below 5 meters (sq. km)
# 4    Urban land area where elevation is below 5 meters (sq. km)
# 5    Forest area (sq. km)
# 6    Land area (sq. km)
# 7    Rural land area (sq. km)
# 8    Urban land area (sq. km)
# 9    Cereal production (metric tons)
# 10   Surface area (sq. km)
# 11   Primary income payments (BoP, current US$)
# 12   Charges for the use of intellectual property, payments (BoP, current US$)
# 13   Foreign direct investment, net outflows (BoP, current US$)
# 14   Secondary income, other sectors, payments (BoP, current US$)
# 15   Personal remittances, paid (current US$)
# 16   Grants, excluding technical cooperation (BoP, current US$)
# 17   Technical cooperation grants (BoP, current US$)
# 18   ICT service exports (BoP, current US$)
# 19   Primary income receipts (BoP, current US$)
# 20   Charges for the use of intellectual property, receipts (BoP, current US$)
# 21   Foreign direct investment, net inflows (BoP, current US$)
# 22   Primary income on FDI (current US$)
# 23   Portfolio equity, net inflows (BoP, current US$)
# 24   Secondary income receipts (BoP, current US$)
# 25   Personal transfers, receipts (BoP, current US$)
# 26   Personal remittances, received (current US$)
# 27   Market capitalization of listed domestic companies (current US$)
# 28   Listed domestic companies, total
# 29   Stocks traded, total value (current US$)
# 30   Net bilateral aid flows from DAC donors, Australia (current US$)
# 31   Net bilateral aid flows from DAC donors, Austria (current US$)
# 32   Net bilateral aid flows from DAC donors, Belgium (current US$)
# 33   Net bilateral aid flows from DAC donors, Canada (current US$)
# 34   Net bilateral aid flows from DAC donors, European Union institutions (current US$)
# 35   Net bilateral aid flows from DAC donors, Switzerland (current US$)
# 36   Net bilateral aid flows from DAC donors, Czech Republic (current US$)
# 37   Net bilateral aid flows from DAC donors, Germany (current US$)
# 38   Net bilateral aid flows from DAC donors, Denmark (current US$)
# 39   Net bilateral aid flows from DAC donors, Spain (current US$)
# 40   Net bilateral aid flows from DAC donors, Finland (current US$)
# 41   Net bilateral aid flows from DAC donors, France (current US$)
# 42   Net bilateral aid flows from DAC donors, United Kingdom (current US$)
# 43   Net bilateral aid flows from DAC donors, Greece (current US$)
# 44   Net bilateral aid flows from DAC donors, Ireland (current US$)
# 45   Net bilateral aid flows from DAC donors, Iceland (current US$)
# 46   Net bilateral aid flows from DAC donors, Italy (current US$)
# 47   Net bilateral aid flows from DAC donors, Japan (current US$)
# 48   Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)
# 49   Net bilateral aid flows from DAC donors, Luxembourg (current US$)
# 50   Net bilateral aid flows from DAC donors, Netherlands (current US$)
# 51   Net bilateral aid flows from DAC donors, Norway (current US$)
# 52   Net bilateral aid flows from DAC donors, New Zealand (current US$)
# 53   Net bilateral aid flows from DAC donors, Poland (current US$)
# 54   Net bilateral aid flows from DAC donors, Portugal (current US$)
# 55   Net bilateral aid flows from DAC donors, Slovak Republic (current US$)
# 56   Net bilateral aid flows from DAC donors, Slovenia (current US$)
# 57   Net bilateral aid flows from DAC donors, Sweden (current US$)
# 58   Net bilateral aid flows from DAC donors, Total (current US$)
# 59   Net bilateral aid flows from DAC donors, United States (current US$)
# 60   PPG, bilateral (AMT, current US$)
# 61   PPG, bilateral concessional (AMT, current US$)
# 62   IMF repurchases (AMT, current US$)
# 63   Principal repayments on external debt, long-term + IMF (AMT, current US$)
# 64   Principal repayments on external debt, long-term (AMT, current US$)
# 65   Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 66   Principal repayments on external debt, public and publicly guaranteed (PPG) (AMT, current US$)
# 67   PPG, IBRD (AMT, current US$)
# 68   PPG, IDA (AMT, current US$)
# 69   PPG, multilateral (AMT, current US$)
# 70   PPG, multilateral concessional (AMT, current US$)
# 71   PPG, official creditors (AMT, current US$)
# 72   PPG, bonds (AMT, current US$)
# 73   PPG, commercial banks (AMT, current US$)
# 74   PNG, bonds (AMT, current US$)
# 75   PNG, commercial banks and other creditors (AMT, current US$)
# 76   PPG, other private creditors (AMT, current US$)
# 77   PPG, private creditors (AMT, current US$)
# 78   Principal arrears, public and publicly guaranteed (current US$)
# 79   Principal arrears, official creditors (current US$)
# 80   Principal arrears, private creditors (current US$)
# 81   Principal forgiven (current US$)
# 82   Principal rescheduled (current US$)
# 83   Principal rescheduled, official (current US$)
# 84   Principal rescheduled, private (current US$)
# 85   Commitments, public and publicly guaranteed (COM, current US$)
# 86   Commitments, IBRD (COM, current US$)
# 87   Commitments, IDA (COM, current US$)
# 88   Commitments, official creditors (COM, current US$)
# 89   Commitments, private creditors (COM, current US$)
# 90   Debt forgiveness or reduction (current US$)
# 91   PPG, bilateral (DIS, current US$)
# 92   PPG, bilateral concessional (DIS, current US$)
# 93   IMF purchases (DIS, current US$)
# 94   Disbursements on external debt, long-term + IMF (DIS, current US$)
# 95   Disbursements on external debt, long-term (DIS, current US$)
# 96   Disbursements on external debt, private nonguaranteed (PNG) (DIS, current US$)
# 97   Disbursements on external debt, public and publicly guaranteed (PPG) (DIS, current US$)
# 98   IDA grants (current US$)
# 99   PPG, IBRD (DIS, current US$)
# 100  PPG, IDA (DIS, current US$)
# 101  PPG, multilateral (DIS, current US$)
# 102  PPG, multilateral concessional (DIS, current US$)
# 103  PPG, official creditors (DIS, current US$)
# 104  PPG, bonds (DIS, current US$)
# 105  PPG, commercial banks (DIS, current US$)
# 106  PNG, bonds (DIS, current US$)
# 107  PNG, commercial banks and other creditors (DIS, current US$)
# 108  PPG, other private creditors (DIS, current US$)
# 109  PPG, private creditors (DIS, current US$)
# 110  External debt stocks, concessional (DOD, current US$)
# 111  PPG, bilateral (DOD, current US$)
# 112  PPG, bilateral concessional (DOD, current US$)
# 113  External debt stocks, total (DOD, current US$)
# 114  Total change in external debt stocks (current US$)
# 115  Use of IMF credit (DOD, current US$)
# 116  External debt stocks, long-term (DOD, current US$)
# 117  External debt stocks, private nonguaranteed (PNG) (DOD, current US$)
# 118  External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)
# 119  External debt stocks, short-term (DOD, current US$)
# 120  Debt forgiveness grants (current US$)
# 121  PPG, IBRD (DOD, current US$)
# 122  PPG, IDA (DOD, current US$)
# 123  PPG, multilateral (DOD, current US$)
# 124  PPG, multilateral concessional (DOD, current US$)
# 125  IBRD loans and IDA credits (DOD, current US$)
# 126  PPG, official creditors (DOD, current US$)
# 127  PPG, bonds (DOD, current US$)
# 128  PPG, commercial banks (DOD, current US$)
# 129  PNG, bonds (DOD, current US$)
# 130  PNG, commercial banks and other creditors (DOD, current US$)
# 131  PPG, other private creditors (DOD, current US$)
# 132  External debt stocks, long-term private sector (DOD, current US$)
# 133  PPG, private creditors (DOD, current US$)
# 134  External debt stocks, long-term public sector (DOD, current US$)
# 135  Present value of external debt (current US$)
# 136  Residual, debt stock-flow reconciliation (current US$)
# 137  External debt stocks, variable rate (DOD, current US$)
# 138  Debt buyback (current US$)
# 139  Debt stock reduction (current US$)
# 140  Debt stock rescheduled (current US$)
# 141  PPG, bilateral (INT, current US$)
# 142  PPG, bilateral concessional (INT, current US$)
# 143  Interest payments on external debt, total (INT, current US$)
# 144  IMF charges (INT, current US$)
# 145  Interest payments on external debt, long-term (INT, current US$)
# 146  Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 147  Interest payments on external debt, public and publicly guaranteed (PPG) (INT, current US$)
# 148  Interest payments on external debt, short-term (INT, current US$)
# 149  PPG, IBRD (INT, current US$)
# 150  PPG, IDA (INT, current US$)
# 151  PPG, multilateral (INT, current US$)
# 152  PPG, multilateral concessional (INT, current US$)
# 153  PPG, official creditors (INT, current US$)
# 154  PPG, bonds (INT, current US$)
# 155  PPG, commercial banks (INT, current US$)
# 156  PNG, bonds (INT, current US$)
# 157  PNG, commercial banks and other creditors (INT, current US$)
# 158  PPG, other private creditors (INT, current US$)
# 159  PPG, private creditors (INT, current US$)
# 160  Interest arrears, public and publicly guaranteed (current US$)
# 161  Net change in interest arrears (current US$)
# 162  Interest arrears, official creditors (current US$)
# 163  Interest arrears, private creditors (current US$)
# 164  Interest forgiven (current US$)
# 165  Interest rescheduled (capitalized) (current US$)
# 166  Interest rescheduled, official (current US$)
# 167  Interest rescheduled, private (current US$)
# 168  Net financial flows, bilateral (NFL, current US$)
# 169  PPG, bilateral concessional (NFL, current US$)
# 170  Portfolio investment, bonds (PPG + PNG) (NFL, current US$)
# 171  Net flows on external debt, total (NFL, current US$)
# 172  Net flows on external debt, long-term (NFL, current US$)
# 173  Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)
# 174  Net flows on external debt, public and publicly guaranteed (PPG) (NFL, current US$)
# 175  Net flows on external debt, short-term (NFL, current US$)
# 176  Net official flows from UN agencies, FAO (current US$)
# 177  Net official flows from UN agencies, IAEA (current US$)
# 178  Net official flows from UN agencies, IFAD (current US$)
# 179  Net official flows from UN agencies, ILO (current US$)
# 180  Net financial flows, IMF concessional (NFL, current US$)
# 181  Net financial flows, IMF nonconcessional (NFL, current US$)
# 182  Net financial flows, IBRD (NFL, current US$)
# 183  Net financial flows, IDA (NFL, current US$)
# 184  Net financial flows, multilateral (NFL, current US$)
# 185  PPG, multilateral concessional (NFL, current US$)
# 186  Net financial flows, others (NFL, current US$)
# 187  EBRD, private nonguaranteed (NFL, current US$)
# 188  IFC, private nonguaranteed (NFL, current US$)
# 189  PPG, official creditors (NFL, current US$)
# 190  PPG, bonds (NFL, current US$)
# 191  PPG, commercial banks (NFL, current US$)
# 192  Commercial banks and other lending (PPG + PNG) (NFL, current US$)
# 193  PNG, bonds (NFL, current US$)
# 194  PNG, commercial banks and other creditors (NFL, current US$)
# 195  PPG, other private creditors (NFL, current US$)
# 196  PPG, private creditors (NFL, current US$)
# 197  Net financial flows, RDB concessional (NFL, current US$)
# 198  Net financial flows, RDB nonconcessional (NFL, current US$)
# 199  Net official flows from UN agencies, UNAIDS (current US$)
# 200  Net official flows from UN agencies, UNICEF (current US$)
# 201  Net official flows from UN agencies, UNHCR (current US$)
# 202  Net official flows from UN agencies, UNDP (current US$)
# 203  Net official flows from UN agencies, UNECE (current US$)
# 204  Net official flows from UN agencies, UNFPA (current US$)
# 205  Net official flows from UN agencies, UNPBF (current US$)
# 206  Net official flows from UN agencies, UNRWA (current US$)
# 207  Net official flows from UN agencies, UNTA (current US$)
# 208  Net official flows from UN agencies, WFP (current US$)
# 209  Net official flows from UN agencies, WHO (current US$)
# 210  PPG, bilateral (NTR, current US$)
# 211  PPG, bilateral concessional (NTR, current US$)
# 212  Net transfers on external debt, total (NTR, current US$)
# 213  Net transfers on external debt, long-term (NTR, current US$)
# 214  Net transfers on external debt, private nonguaranteed (PNG) (NTR, current US$)
# 215  Net transfers on external debt, public and publicly guaranteed (PPG) (NTR, current US$)
# 216  PPG, IBRD (NTR, current US$)
# 217  PPG, IDA (NTR, current US$)
# 218  PPG, multilateral (NTR, current US$)
# 219  PPG, multilateral concessional (NTR, current US$)
# 220  PPG, official creditors (NTR, current US$)
# 221  PPG, bonds (NTR, current US$)
# 222  PPG, commercial banks (NTR, current US$)
# 223  PNG, bonds (NTR, current US$)
# 224  PNG, commercial banks and other creditors (NTR, current US$)
# 225  PPG, other private creditors (NTR, current US$)
# 226  PPG, private creditors (NTR, current US$)
# 227  Net official development assistance and official aid received (current US$)
# 228  Net official development assistance and official aid received (constant 2013 US$)
# 229  Net official aid received (current US$)
# 230  Net official aid received (constant 2014 US$)
# 231  Net official development assistance received (current US$)
# 232  Net official development assistance received (constant 2014 US$)
# 233  PPG, bilateral (TDS, current US$)
# 234  PPG, bilateral concessional (TDS, current US$)
# 235  Debt service on external debt, total (TDS, current US$)
# 236  IMF repurchases and charges (TDS, current US$)
# 237  Debt service on external debt, long-term (TDS, current US$)
# 238  Debt service on external debt, private nonguaranteed (PNG) (TDS, current US$)
# 239  Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)
# 240  PPG, IBRD (TDS, current US$)
# 241  PPG, IDA (TDS, current US$)
# 242  Multilateral debt service (TDS, current US$)
# 243  PPG, multilateral concessional (TDS, current US$)
# 244  PPG, official creditors (TDS, current US$)
# 245  PPG, bonds (TDS, current US$)
# 246  PPG, commercial banks (TDS, current US$)
# 247  PNG, bonds (TDS, current US$)
# 248  PNG, commercial banks and other creditors (TDS, current US$)
# 249  PPG, other private creditors (TDS, current US$)
# 250  PPG, private creditors (TDS, current US$)
# 251  Total amount of debt rescheduled (current US$)
# 252  Undisbursed external debt, total (UND, current US$)
# 253  Undisbursed external debt, official creditors (UND, current US$)
# 254  Undisbursed external debt, private creditors (UND, current US$)
# 255  Electricity production from renewable sources, excluding hydroelectric (kWh)
# 256  Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)
# 257  Total greenhouse gas emissions (kt of CO2 equivalent)
# 258  Agricultural methane emissions (thousand metric tons of CO2 equivalent)
# 259  Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
# 260  Methane emissions (kt of CO2 equivalent)
# 261  Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# 262  Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)
# 263  Nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# 264  Bird species, threatened
# 265  Fish species, threatened
# 266  Plant species (higher), threatened
# 267  Mammal species, threatened
# 268  Aquaculture production (metric tons)
# 269  Capture fisheries production (metric tons)
# 270  Total fisheries production (metric tons)
# 271  Annual freshwater withdrawals, total (billion cubic meters)
# 272  Renewable internal freshwater resources, total (billion cubic meters)
# 273  Investment in energy with private participation (current US$)
# 274  Investment in ICT with private participation (current US$)
# 275  Investment in telecoms with private participation (current US$)
# 276  Investment in transport with private participation (current US$)
# 277  Investment in water and sanitation with private participation (current US$)
# 278  Public private partnerships investment in energy (current US$)
# 279  Public private partnerships investment in ICT (current US$)
# 280  Public private partnerships investment in telecom (current US$)
# 281  Public private partnerships investment in transport (current US$)
# 282  Public private partnerships investment in water and sanitation (current US$)
# 283  Industrial design applications, nonresident, by count
# 284  Industrial design applications, resident, by count
# 285  Patent applications, nonresidents
# 286  Patent applications, residents
# 287  Trademark applications, nonresident, by count
# 288  Trademark applications, direct nonresident
# 289  Trademark applications, direct resident
# 290  Trademark applications, resident, by count
# 291  Trademark applications, total
# 292  Air transport, registered carrier departures worldwide
# 293  Air transport, freight (million ton-km)
# 294  Air transport, passengers carried
# 295  Rail lines (total route-km)
# 296  Container port traffic (TEU: 20 foot equivalent units)
# 297  Mobile cellular subscriptions
# 298  Fixed telephone subscriptions
# 299  Fixed broadband subscriptions
# 300  Secure Internet servers
# 301  Arms imports (SIPRI trend indicator values)
# 302  Armed forces personnel, total
# 303  Arms exports (SIPRI trend indicator values)
# 304  Primary education, pupils
# 305  Primary education, teachers
# 306  Children out of school, primary
# 307  Children out of school, primary, female
# 308  Children out of school, primary, male
# 309  Secondary education, pupils
# 310  Secondary education, general pupils
# 311  Secondary education, vocational pupils
# 312  Secondary education, teachers
# 313  Secondary education, teachers, female
# 314  Number of deaths ages 5-14 years
# 315  Number of infant deaths
# 316  Number of under-five deaths
# 317  Number of neonatal deaths
# 318  Number of maternal deaths
# 319  Number of people pushed below the $1.90 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure
# 320  Number of people pushed below the $3.10 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure
# 321  Number of people spending more than 10% of household consumption or income on out-of-pocket health care expenditure
# 322  Number of people spending more than 25% of household consumption or income on out-of-pocket health care expenditure
# 323  Labor force, total
# 324  Net migration
# 325  Refugee population by country or territory of asylum
# 326  Refugee population by country or territory of origin
# 327  International migrant stock, total
# 328  Population ages 0-14, female
# 329  Population ages 0-14, male
# 330  Population ages 0-14, total
# 331  Population ages 15-64, female
# 332  Population ages 15-64, male
# 333  Population ages 15-64, total
# 334  Population ages 65 and above, female
# 335  Population ages 65 and above, male
# 336  Population ages 65 and above, total
# 337  Population, total
# 338  Population, female
# 339  Population, male
# 340  Rural population
# 341  Urban population
# 342  Merchandise imports by the reporting economy (current US$)
# 343  Merchandise exports by the reporting economy (current US$)
# 344  High-technology exports (current US$)
# 345  Battle-related deaths (number of people)
# 346  Internally displaced persons, new displacement associated with conflict and violence (number of cases)
# 347  Internally displaced persons, new displacement associated with disasters (number of cases)
# 348  Internally displaced persons, total displaced by conflict and violence (number of people)
# 349  Presence of peace keepers (number of troops, police, and military observers in mandate)

# %% [markdown]
# ##### Only keep the indicators that are relevant to requirements i.e. Population indicators and Cellular and Broadband penetration

# %%
targetIndicators = simpleAggIndicators \
    .filter("lower(indicator_name) like '%population%total%' " + 
            " or lower(indicator_name) like '%cellular%' " +
            " or lower(indicator_name) like '%broadband%'") \
    .filter("lower(indicator_name) not like '%refugee%'")

showDF(targetIndicators)
# Out:
#    indicator_code                       indicator_name
# 0     IT.CEL.SETS        Mobile cellular subscriptions
# 1     IT.NET.BBND        Fixed broadband subscriptions
# 2  SP.POP.0014.TO          Population ages 0-14, total
# 3  SP.POP.1564.TO         Population ages 15-64, total
# 4  SP.POP.65UP.TO  Population ages 65 and above, total
# 5     SP.POP.TOTL                    Population, total

# %% [markdown]
# ##### Now that we have identified the various indicators of interest, we can continue with getting the metrics for these indicators

# %%
# Keep the columns that are relevant for further transformations
indicatorsData = indicators \
    .withColumnRenamed("Indicator Code", "indicator_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .drop("Indicator Name") \
    .drop("Country Name") \
    .drop("_c62")

# %%
#Keep only the indicators that we care about
targetIndicatorsData = indicatorsData.join(targetIndicators \
                                         , indicatorsData.indicator_code == targetIndicators.indicator_code) \
    .drop(targetIndicators.indicator_code)

# %%
showDF(targetIndicatorsData)
# Out:
#    wb_country_code  indicator_code        1960        1961        1962  \
# 0              ARB     IT.NET.BBND         NaN         NaN         NaN
# 1              ARB     IT.CEL.SETS         0.0         NaN         NaN
# 2              ARB  SP.POP.0014.TO  40064255.0  41518715.0  42987169.0
# 3              ARB  SP.POP.1564.TO  49179481.0  50158016.0  51208328.0
# 4              ARB  SP.POP.65UP.TO   3247196.0   3367766.0   3486797.0
# 5              ARB     SP.POP.TOTL  92490932.0  95044497.0  97682294.0
# 6              CSS     IT.NET.BBND         NaN         NaN         NaN
# 7              CSS     IT.CEL.SETS         0.0         NaN         NaN
# 8              CSS  SP.POP.0014.TO   1766884.0   1816372.0   1864013.0
# 9              CSS  SP.POP.1564.TO   2151060.0   2173846.0   2198714.0
# 12  1.676303e+07  1.805184e+07  2.020864e+07  2.088233e+07  2.197775e+07
# 13  1.263254e+08  1.282832e+08  1.312328e+08  1.357431e+08  1.379437e+08
# 14  1.583863e+07  1.569344e+07  1.563016e+07  1.555406e+07  1.547474e+07
# 15  7.339997e+07  7.304396e+07  7.251681e+07  7.205201e+07  7.155604e+07
# 16  1.568577e+07  1.580640e+07  1.602707e+07  1.632924e+07  1.668294e+07
# 17  1.049244e+08  1.045438e+08  1.041740e+08  1.039353e+08  1.037137e+08
# 18  4.202646e+07  4.905381e+07  5.949271e+07  6.929925e+07  7.716696e+07
# 19  1.594519e+09  1.980489e+09  2.287218e+09  2.386166e+09  2.532464e+09
#
#             2014          2015          2016  2017  \
# 0   1.383407e+07  1.660445e+07  1.852699e+07   NaN
# 1   4.150294e+08  4.171956e+08  4.123153e+08   NaN
# 2   1.299870e+08  1.324654e+08  1.350077e+08   NaN
# 3   2.434054e+08  2.486149e+08  2.535661e+08   NaN
# 4   1.665064e+07  1.722468e+07  1.787893e+07   NaN
# 5   3.900430e+08  3.983050e+08  4.064527e+08   NaN
# 6   7.533680e+05  8.971340e+05  9.818860e+05   NaN
# 7   7.952805e+06  8.158698e+06  8.487436e+06   NaN
# 8   1.717638e+06  1.700765e+06  1.687271e+06   NaN
# 9   4.739145e+06  4.781112e+06  4.816676e+06   NaN
# 10  5.793790e+05  5.956210e+05  6.131610e+05   NaN
# 11  7.162679e+06  7.204948e+06  7.245472e+06   NaN
# 12  2.271588e+07  2.335264e+07  2.410117e+07   NaN
# 13  1.366668e+08  1.332150e+08  1.316835e+08   NaN
# 14  1.542814e+07  1.542244e+07  1.534312e+07   NaN
# 15  7.100241e+07  7.037545e+07  6.973236e+07   NaN
# 16  1.706563e+07  1.745986e+07  1.791584e+07   NaN
# 17  1.034962e+08  1.032578e+08  1.029913e+08   NaN
# 18  8.621924e+07  9.952776e+07  1.112343e+08   NaN
# 19  2.659775e+09  2.789512e+09  3.009125e+09   NaN
#
#                          indicator_name
# 0         Fixed broadband subscriptions
# 1         Mobile cellular subscriptions
# 2           Population ages 0-14, total
# 3          Population ages 15-64, total
# 4   Population ages 65 and above, total
# 5                     Population, total
# 6         Fixed broadband subscriptions
# 7         Mobile cellular subscriptions
# 8           Population ages 0-14, total
# 9          Population ages 15-64, total
# 10  Population ages 65 and above, total
# 11                    Population, total
# 12        Fixed broadband subscriptions
# 13        Mobile cellular subscriptions
# 14          Population ages 0-14, total
# 15         Population ages 15-64, total
# 16  Population ages 65 and above, total
# 17                    Population, total
# 18        Fixed broadband subscriptions
# 19        Mobile cellular subscriptions
#
# [20 rows x 61 columns]

# %% [markdown]
# #### The output that we see currently isn't the most ideal from a modelling perspective.
# A well modeled dataset, should allow for data to be easily augmented.  e.g. instead of having a column for each year we would ideally prefer a row for each year to be able to add more rows in the future similar to the output of the following code block.

# %%
indicatorsSample = targetIndicatorsData \
    .select(col("wb_country_code")
            , col("indicator_code")
            , lit("1960").alias("year")
            , col("1960").alias("indicator_value")) \
    .filter("indicator_value >= 0.0")

showDF(indicatorsSample)
# Out:
#    wb_country_code  indicator_code  year  indicator_value
# 0              ARB     IT.CEL.SETS  1960              0.0
# 1              ARB  SP.POP.0014.TO  1960       40064255.0
# 2              ARB  SP.POP.1564.TO  1960       49179481.0
# 3              ARB  SP.POP.65UP.TO  1960        3247196.0
# 4              ARB     SP.POP.TOTL  1960       92490932.0
# 5              CSS     IT.CEL.SETS  1960              0.0
# 6              CSS  SP.POP.0014.TO  1960        1766884.0
# 7              CSS  SP.POP.1564.TO  1960        2151060.0
# 8              CSS  SP.POP.65UP.TO  1960         169157.0
# 9              CSS     SP.POP.TOTL  1960        4198307.0
# 10             CEB     IT.CEL.SETS  1960              0.0
# 11             CEB  SP.POP.0014.TO  1960       26671149.0
# 12             CEB  SP.POP.1564.TO  1960       58135954.0
# 13             CEB  SP.POP.65UP.TO  1960        6594481.0
# 14             CEB     SP.POP.TOTL  1960       91401583.0
# 15             EAR     IT.CEL.SETS  1960              0.0
# 16             EAR  SP.POP.0014.TO  1960      403027249.0
# 17             EAR  SP.POP.1564.TO  1960      543753940.0
# 18             EAR  SP.POP.65UP.TO  1960       32506217.0
# 19             EAR     SP.POP.TOTL  1960      979287407.0

# %% [markdown]
# ##### Let us start by getting the list of years that we have metrics for

# %%
yearList = [x for x in targetIndicatorsData.schema.names \
             if x != 'wb_country_code' and x != 'indicator_code' and x != 'indicator_name'] 

print(yearList)
# Out:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
#Cheat for creating a dataframe with no rows 
indicatorsDF = indicatorsSample.filter('1 = 0')

#Iterate through the list of years and store the rows in the DataFrame we created above
for indicatorYear in yearList:
    print("Processing indicators for " + indicatorYear)
    yearIndicatorDF = targetIndicatorsData \
        .select(col("wb_country_code")
                , col("indicator_code")
                , lit(indicatorYear).alias("year")
                , col(indicatorYear).alias("indicator_value")) \
        .filter("indicator_value >= 0")
    indicatorsDF = indicatorsDF.union(yearIndicatorDF)
# Out:
# Processing indicators for 1960
# Processing indicators for 1961
# Processing indicators for 1962
# Processing indicators for 1963
# Processing indicators for 1964
# Processing indicators for 1965
# Processing indicators for 1966
# Processing indicators for 1967
# Processing indicators for 1968
# Processing indicators for 1969
# Processing indicators for 1970
# Processing indicators for 1971
# Processing indicators for 1972
# Processing indicators for 1973
# Processing indicators for 1974
# Processing indicators for 1975
# Processing indicators for 1976
# Processing indicators for 1977
# Processing indicators for 1978
# Processing indicators for 1979
# Processing indicators for 1980
# Processing indicators for 1981
# Processing indicators for 1982
# Processing indicators for 1983
# Processing indicators for 1984
# Processing indicators for 1985
# Processing indicators for 1986
# Processing indicators for 1987
# Processing indicators for 1988
# Processing indicators for 1989
# Processing indicators for 1990
# Processing indicators for 1991
# Processing indicators for 1992
# Processing indicators for 1993
# Processing indicators for 1994
# Processing indicators for 1995
# Processing indicators for 1996
# Processing indicators for 1997
# Processing indicators for 1998
# Processing indicators for 1999
# Processing indicators for 2000
# Processing indicators for 2001
# Processing indicators for 2002
# Processing indicators for 2003
# Processing indicators for 2004
# Processing indicators for 2005
# Processing indicators for 2006
# Processing indicators for 2007
# Processing indicators for 2008
# Processing indicators for 2009
# Processing indicators for 2010
# Processing indicators for 2011
# Processing indicators for 2012
# Processing indicators for 2013
# Processing indicators for 2014
# Processing indicators for 2015
# Processing indicators for 2016
# Processing indicators for 2017

# %% [markdown]
# #### Let's cache the dataset to iterate over it

# %%
# You can iterate over a dataframe that is already computed by caching it onces and using it repeatedly
indicatorsDF.cache()

#Force the data to be cached
indicatorsDF.count()

showDF(indicatorsDF, limitRows=30)
# Out:
#    wb_country_code  indicator_code  year  indicator_value
# 0              ARB     IT.CEL.SETS  1960     0.000000e+00
# 1              ARB  SP.POP.0014.TO  1960     4.006426e+07
# 2              ARB  SP.POP.1564.TO  1960     4.917948e+07
# 3              ARB  SP.POP.65UP.TO  1960     3.247196e+06
# 4              ARB     SP.POP.TOTL  1960     9.249093e+07
# 5              CSS     IT.CEL.SETS  1960     0.000000e+00
# 6              CSS  SP.POP.0014.TO  1960     1.766884e+06
# 7              CSS  SP.POP.1564.TO  1960     2.151060e+06
# 8              CSS  SP.POP.65UP.TO  1960     1.691570e+05
# 9              CSS     SP.POP.TOTL  1960     4.198307e+06
# 10             CEB     IT.CEL.SETS  1960     0.000000e+00
# 11             CEB  SP.POP.0014.TO  1960     2.667115e+07
# 12             CEB  SP.POP.1564.TO  1960     5.813595e+07
# 13             CEB  SP.POP.65UP.TO  1960     6.594481e+06
# 14             CEB     SP.POP.TOTL  1960     9.140158e+07
# 15             EAR     IT.CEL.SETS  1960     0.000000e+00
# 16             EAR  SP.POP.0014.TO  1960     4.030272e+08
# 17             EAR  SP.POP.1564.TO  1960     5.437539e+08
# 18             EAR  SP.POP.65UP.TO  1960     3.250622e+07
# 19             EAR     SP.POP.TOTL  1960     9.792874e+08
# 20             EAS     IT.CEL.SETS  1960     0.000000e+00
# 21             EAS  SP.POP.0014.TO  1960     4.076647e+08
# 22             EAS  SP.POP.1564.TO  1960     5.918464e+08
# 23             EAS  SP.POP.65UP.TO  1960     4.036861e+07
# 24             EAS     SP.POP.TOTL  1960     1.039945e+09
# 25             EAP     IT.CEL.SETS  1960     0.000000e+00
# 26             EAP  SP.POP.0014.TO  1960     3.580054e+08
# 27             EAP  SP.POP.1564.TO  1960     5.030815e+08
# 28             EAP  SP.POP.65UP.TO  1960     3.282421e+07
# 29             EAP     SP.POP.TOTL  1960     8.939563e+08

# %%
#Check the indicator counts per year
showDF(indicatorsDF.groupBy('year').agg(count("*")).orderBy("year"), limitRows=100)
# Out:
#     year  count(1)
# 0   1960      1220
# 1   1961       974
# 2   1962       974
# 3   1963       974
# 4   1964       974
# 5   1965      1220
# 6   1966       974
# 7   1967       974
# 8   1968       974
# 9   1969       974
# 10  1970      1220
# 11  1971       974
# 12  1972       974
# 13  1973       974
# 14  1974       974
# 15  1975      1220
# 16  1976      1220
# 17  1977      1220
# 18  1978      1220
# 19  1979      1220
# 20  1980      1220
# 21  1981      1218
# 22  1982      1218
# 23  1983      1217
# 24  1984      1216
# 25  1985      1215
# 26  1986      1216
# 27  1987      1214
# 28  1988      1215
# 29  1989      1213
# 30  1990      1235
# 31  1991      1224
# 32  1992      1222
# 33  1993      1222
# 34  1994      1222
# 35  1995      1228
# 36  1996      1229
# 37  1997      1228
# 38  1998      1242
# 39  1999      1247
# 40  2000      1291
# 41  2001      1333
# 42  2002      1371
# 43  2003      1393
# 44  2004      1411
# 45  2005      1441
# 46  2006      1433
# 47  2007      1460
# 48  2008      1467
# 49  2009      1471
# 50  2010      1481
# 51  2011      1466
# 52  2012      1474
# 53  2013      1477
# 54  2014      1478
# 55  2015      1481
# 56  2016      1466

# %% [markdown]
# #### Getting yearly indicator totals

# %%
yearPivot = indicatorsDF.groupBy('year').pivot('indicator_code').sum('indicator_value')

# %%
showDF(yearPivot.orderBy('year'))
# Out:
#     year  IT.CEL.SETS  IT.NET.BBND  SP.POP.0014.TO  SP.POP.1564.TO  \
# 0   1960          0.0          NaN    1.164043e+10    1.764656e+10
# 1   1961          NaN          NaN    1.186066e+10    1.780707e+10
# 2   1962          NaN          NaN    1.215358e+10    1.803340e+10
# 3   1963          NaN          NaN    1.249841e+10    1.834110e+10
# 4   1964          NaN          NaN    1.281722e+10    1.868178e+10
# 5   1965          0.0          NaN    1.310455e+10    1.907143e+10
# 6   1966          NaN          NaN    1.343731e+10    1.943187e+10
# 7   1967          NaN          NaN    1.371767e+10    1.984342e+10
# 8   1968          NaN          NaN    1.396924e+10    2.029706e+10
# 9   1969          NaN          NaN    1.422516e+10    2.078273e+10
# 10  1970          0.0          NaN    1.449018e+10    2.127209e+10
# 11  1971          NaN          NaN    1.478645e+10    2.173800e+10
# 12  1972          NaN          NaN    1.507061e+10    2.221091e+10
# 13  1973          NaN          NaN    1.534245e+10    2.269287e+10
# 14  1974          NaN          NaN    1.559221e+10    2.319928e+10
# 15  1975          0.0          NaN    1.580695e+10    2.372537e+10
# 16  1976          0.0          NaN    1.601854e+10    2.422892e+10
# 17  1977          0.0          NaN    1.619743e+10    2.476186e+10
# 18  1978          0.0          NaN    1.635522e+10    2.533091e+10
# 19  1979          0.0          NaN    1.650413e+10    2.593300e+10
#
#     SP.POP.65UP.TO   SP.POP.TOTL
# 0     1.419169e+09  3.072052e+10
# 1     1.451321e+09  3.113369e+10
# 2     1.483492e+09  3.168550e+10
# 3     1.517104e+09  3.237204e+10
# 4     1.549219e+09  3.306404e+10
# 5     1.581083e+09  3.377327e+10
# 6     1.634468e+09  3.452025e+10
# 7     1.687816e+09  3.526591e+10
# 8     1.741146e+09  3.602484e+10
# 9     1.795141e+09  3.682082e+10
# 10    1.848060e+09  3.762852e+10
# 11    1.912749e+09  3.845576e+10
# 12    1.975038e+09  3.927555e+10
# 13    2.035301e+09  4.009001e+10
# 14    2.095556e+09  4.090685e+10
# 15    2.155471e+09  4.170800e+10
# 16    2.227452e+09  4.249554e+10
# 17    2.299457e+09  4.327978e+10
# 18    2.369935e+09  4.407752e+10
# 19    2.435092e+09  4.489408e+10

# %%
yearPivot.printSchema()
# Out:
# root
#  |-- year: string (nullable = false)
#  |-- IT.CEL.SETS: double (nullable = true)
#  |-- IT.NET.BBND: double (nullable = true)
#  |-- SP.POP.0014.TO: double (nullable = true)
#  |-- SP.POP.1564.TO: double (nullable = true)
#  |-- SP.POP.65UP.TO: double (nullable = true)
#  |-- SP.POP.TOTL: double (nullable = true)

# %%
yearPivotDF = yearPivot.orderBy('year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population')

# %% [markdown]
# #### Data Quality Checkpoint

# %%
# You can iterate over a dataframe that is already computed by caching it onces and using it repeatedly
yearPivotDF.cache()

#Forces the data to be cached
yearPivotDF.count()
# Out:
# 57

# %%
yearPivotDF.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_15_64 < 0').count()
# Out:
# [Stage 100:================================================>      (50 + 4) / 57]
# 0

# %%
yearPivotDF.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_65_and_above < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('cellular_subscriptions < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('broadband_subscriptions < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_0_to_14 > population').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_15_64 > population').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_65_and_above > population').count()
# Out:
# 0

# %%
yearPivotDF.filter('(population_age_0_to_14 + population_age_15_64 + population_age_65_and_above) > population').count()
# Out:
# 0

# %%
#Write the yearly totals to a CSV File
yearPivotDF \
    .select(col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('../output/YearlyStats', mode='overwrite', header='true')

# %% [markdown]
# #### Getting yearly regional totals

# %%
regionalIndicators = indicatorsDF.join(countryDimFinal
                                       , indicatorsDF.wb_country_code == countryDim.wb_country_code
                                       , "inner") \
    .select(countryDim.region
            , indicatorsDF.wb_country_code
            , indicatorsDF.year
            , indicatorsDF.indicator_code
            , indicatorsDF.indicator_value)

# %%
showDF(regionalIndicators, limitRows=1000)
# Out:
#                          region wb_country_code  year  indicator_code  \
# 0                          None             ARB  1960     IT.CEL.SETS
# 1                          None             ARB  1960  SP.POP.0014.TO
# 2                          None             ARB  1960  SP.POP.1564.TO
# 3                          None             ARB  1960  SP.POP.65UP.TO
# 4                          None             ARB  1960     SP.POP.TOTL
# 5                          None             CSS  1960     IT.CEL.SETS
# 6                          None             CSS  1960  SP.POP.0014.TO
# 7                          None             CSS  1960  SP.POP.1564.TO
# 8                          None             CSS  1960  SP.POP.65UP.TO
# 9                          None             CSS  1960     SP.POP.TOTL
# 10                         None             CEB  1960     IT.CEL.SETS
# 11                         None             CEB  1960  SP.POP.0014.TO
# 12                         None             CEB  1960  SP.POP.1564.TO
# 13                         None             CEB  1960  SP.POP.65UP.TO
# 14                         None             CEB  1960     SP.POP.TOTL
# 15                         None             EAR  1960     IT.CEL.SETS
# 16                         None             EAR  1960  SP.POP.0014.TO
# 17                         None             EAR  1960  SP.POP.1564.TO
# 18                         None             EAR  1960  SP.POP.65UP.TO
# 19                         None             EAR  1960     SP.POP.TOTL
# 20                         None             EAS  1960     IT.CEL.SETS
# 21                         None             EAS  1960  SP.POP.0014.TO
# 22                         None             EAS  1960  SP.POP.1564.TO
# 23                         None             EAS  1960  SP.POP.65UP.TO
# 24                         None             EAS  1960     SP.POP.TOTL
# 25                         None             EAP  1960     IT.CEL.SETS
# 26                         None             EAP  1960  SP.POP.0014.TO
# 27                         None             EAP  1960  SP.POP.1564.TO
# 28                         None             EAP  1960  SP.POP.65UP.TO
# 29                         None             EAP  1960     SP.POP.TOTL
# 30                         None             TEA  1960     IT.CEL.SETS
# 31                         None             TEA  1960  SP.POP.0014.TO
# 32                         None             TEA  1960  SP.POP.1564.TO
# 33                         None             TEA  1960  SP.POP.65UP.TO
# 34                         None             TEA  1960     SP.POP.TOTL
# 35                         None             EMU  1960     IT.CEL.SETS
# 36                         None             EMU  1960  SP.POP.0014.TO
# 37                         None             EMU  1960  SP.POP.1564.TO
# 38                         None             EMU  1960  SP.POP.65UP.TO
# 39                         None             EMU  1960     SP.POP.TOTL
# 40                         None             ECS  1960     IT.CEL.SETS
# 41                         None             ECS  1960  SP.POP.0014.TO
# 42                         None             ECS  1960  SP.POP.1564.TO
# 43                         None             ECS  1960  SP.POP.65UP.TO
# 44                         None             ECS  1960     SP.POP.TOTL
# 45                         None             ECA  1960     IT.CEL.SETS
# 46                         None             ECA  1960  SP.POP.0014.TO
# 47                         None             ECA  1960  SP.POP.1564.TO
# 48                         None             ECA  1960  SP.POP.65UP.TO
# 49                         None             ECA  1960     SP.POP.TOTL
# 50                         None             TEC  1960     IT.CEL.SETS
# 51                         None             TEC  1960  SP.POP.0014.TO
# 52                         None             TEC  1960  SP.POP.1564.TO
# 53                         None             TEC  1960  SP.POP.65UP.TO
# 54                         None             TEC  1960     SP.POP.TOTL
# 55                         None             EUU  1960     IT.CEL.SETS
# 56                         None             EUU  1960  SP.POP.0014.TO
# 57                         None             EUU  1960  SP.POP.1564.TO
# 58                         None             EUU  1960  SP.POP.65UP.TO
# 59                         None             EUU  1960     SP.POP.TOTL
# 60                         None             FCS  1960     IT.CEL.SETS
# 61                         None             FCS  1960  SP.POP.0014.TO
# 62                         None             FCS  1960  SP.POP.1564.TO
# 63                         None             FCS  1960  SP.POP.65UP.TO
# 64                         None             FCS  1960     SP.POP.TOTL
# 65                         None             HPC  1960     IT.CEL.SETS
# 66                         None             HPC  1960  SP.POP.0014.TO
# 67                         None             HPC  1960  SP.POP.1564.TO
# 68                         None             HPC  1960  SP.POP.65UP.TO
# 69                         None             HPC  1960     SP.POP.TOTL
# 70                         None             HIC  1960     IT.CEL.SETS
# 71                         None             HIC  1960  SP.POP.0014.TO
# 72                         None             HIC  1960  SP.POP.1564.TO
# 73                         None             HIC  1960  SP.POP.65UP.TO
# 74                         None             HIC  1960     SP.POP.TOTL
# 75                         None             IBD  1960     IT.CEL.SETS
# 76                         None             IBD  1960  SP.POP.0014.TO
# 77                         None             IBD  1960  SP.POP.1564.TO
# 78                         None             IBD  1960  SP.POP.65UP.TO
# 79                         None             IBD  1960     SP.POP.TOTL
# 80                         None             IBT  1960     IT.CEL.SETS
# 81                         None             IBT  1960  SP.POP.0014.TO
# 82                         None             IBT  1960  SP.POP.1564.TO
# 83                         None             IBT  1960  SP.POP.65UP.TO
# 84                         None             IBT  1960     SP.POP.TOTL
# 85                         None             IDB  1960     IT.CEL.SETS
# 86                         None             IDB  1960  SP.POP.0014.TO
# 87                         None             IDB  1960  SP.POP.1564.TO
# 88                         None             IDB  1960  SP.POP.65UP.TO
# 89                         None             IDB  1960     SP.POP.TOTL
# 90                         None             IDX  1960     IT.CEL.SETS
# 91                         None             IDX  1960  SP.POP.0014.TO
# 92                         None             IDX  1960  SP.POP.1564.TO
# 93                         None             IDX  1960  SP.POP.65UP.TO
# 94                         None             IDX  1960     SP.POP.TOTL
# 95                         None             IDA  1960     IT.CEL.SETS
# 96                         None             IDA  1960  SP.POP.0014.TO
# 97                         None             IDA  1960  SP.POP.1564.TO
# 98                         None             IDA  1960  SP.POP.65UP.TO
# 99                         None             IDA  1960     SP.POP.TOTL
# 100                        None             LTE  1960     IT.CEL.SETS
# 101                        None             LTE  1960  SP.POP.0014.TO
# 102                        None             LTE  1960  SP.POP.1564.TO
# 103                        None             LTE  1960  SP.POP.65UP.TO
# 104                        None             LTE  1960     SP.POP.TOTL
# 105                        None             LCN  1960     IT.CEL.SETS
# 106                        None             LCN  1960  SP.POP.0014.TO
# 107                        None             LCN  1960  SP.POP.1564.TO
# 108                        None             LCN  1960  SP.POP.65UP.TO
# 109                        None             LCN  1960     SP.POP.TOTL
# 110                        None             LAC  1960     IT.CEL.SETS
# 111                        None             LAC  1960  SP.POP.0014.TO
# 112                        None             LAC  1960  SP.POP.1564.TO
# 113                        None             LAC  1960  SP.POP.65UP.TO
# 114                        None             LAC  1960     SP.POP.TOTL
# 115                        None             TLA  1960     IT.CEL.SETS
# 116                        None             TLA  1960  SP.POP.0014.TO
# 117                        None             TLA  1960  SP.POP.1564.TO
# 118                        None             TLA  1960  SP.POP.65UP.TO
# 119                        None             TLA  1960     SP.POP.TOTL
# 120                        None             LDC  1960     IT.CEL.SETS
# 121                        None             LDC  1960  SP.POP.0014.TO
# 122                        None             LDC  1960  SP.POP.1564.TO
# 123                        None             LDC  1960  SP.POP.65UP.TO
# 124                        None             LDC  1960     SP.POP.TOTL
# 125                        None             LMY  1960     IT.CEL.SETS
# 126                        None             LMY  1960  SP.POP.0014.TO
# 127                        None             LMY  1960  SP.POP.1564.TO
# 128                        None             LMY  1960  SP.POP.65UP.TO
# 129                        None             LMY  1960     SP.POP.TOTL
# 130                        None             LIC  1960     IT.CEL.SETS
# 131                        None             LIC  1960  SP.POP.0014.TO
# 132                        None             LIC  1960  SP.POP.1564.TO
# 133                        None             LIC  1960  SP.POP.65UP.TO
# 134                        None             LIC  1960     SP.POP.TOTL
# 135                        None             LMC  1960     IT.CEL.SETS
# 136                        None             LMC  1960  SP.POP.0014.TO
# 137                        None             LMC  1960  SP.POP.1564.TO
# 138                        None             LMC  1960  SP.POP.65UP.TO
# 139                        None             LMC  1960     SP.POP.TOTL
# 140                        None             MEA  1960     IT.CEL.SETS
# 141                        None             MEA  1960  SP.POP.0014.TO
# 142                        None             MEA  1960  SP.POP.1564.TO
# 143                        None             MEA  1960  SP.POP.65UP.TO
# 144                        None             MEA  1960     SP.POP.TOTL
# 145                        None             MNA  1960     IT.CEL.SETS
# 146                        None             MNA  1960  SP.POP.0014.TO
# 147                        None             MNA  1960  SP.POP.1564.TO
# 148                        None             MNA  1960  SP.POP.65UP.TO
# 149                        None             MNA  1960     SP.POP.TOTL
# 150                        None             TMN  1960     IT.CEL.SETS
# 151                        None             TMN  1960  SP.POP.0014.TO
# 152                        None             TMN  1960  SP.POP.1564.TO
# 153                        None             TMN  1960  SP.POP.65UP.TO
# 154                        None             TMN  1960     SP.POP.TOTL
# 155                        None             MIC  1960     IT.CEL.SETS
# 156                        None             MIC  1960  SP.POP.0014.TO
# 157                        None             MIC  1960  SP.POP.1564.TO
# 158                        None             MIC  1960  SP.POP.65UP.TO
# 159                        None             MIC  1960     SP.POP.TOTL
# 160                        None             NAC  1960     IT.CEL.SETS
# 161                        None             NAC  1960  SP.POP.0014.TO
# 162                        None             NAC  1960  SP.POP.1564.TO
# 163                        None             NAC  1960  SP.POP.65UP.TO
# 164                        None             NAC  1960     SP.POP.TOTL
# 165                        None             OED  1960     IT.CEL.SETS
# 166                        None             OED  1960  SP.POP.0014.TO
# 167                        None             OED  1960  SP.POP.1564.TO
# 168                        None             OED  1960  SP.POP.65UP.TO
# 169                        None             OED  1960     SP.POP.TOTL
# 170                        None             OSS  1960     IT.CEL.SETS
# 171                        None             OSS  1960  SP.POP.0014.TO
# 172                        None             OSS  1960  SP.POP.1564.TO
# 173                        None             OSS  1960  SP.POP.65UP.TO
# 174                        None             OSS  1960     SP.POP.TOTL
# 175                        None             PSS  1960     IT.CEL.SETS
# 176                        None             PSS  1960  SP.POP.0014.TO
# 177                        None             PSS  1960  SP.POP.1564.TO
# 178                        None             PSS  1960  SP.POP.65UP.TO
# 179                        None             PSS  1960     SP.POP.TOTL
# 180                        None             PST  1960     IT.CEL.SETS
# 181                        None             PST  1960  SP.POP.0014.TO
# 182                        None             PST  1960  SP.POP.1564.TO
# 183                        None             PST  1960  SP.POP.65UP.TO
# 184                        None             PST  1960     SP.POP.TOTL
# 185                        None             PRE  1960     IT.CEL.SETS
# 186                        None             PRE  1960  SP.POP.0014.TO
# 187                        None             PRE  1960  SP.POP.1564.TO
# 188                        None             PRE  1960  SP.POP.65UP.TO
# 189                        None             PRE  1960     SP.POP.TOTL
# 190                        None             SST  1960     IT.CEL.SETS
# 191                        None             SST  1960  SP.POP.0014.TO
# 192                        None             SST  1960  SP.POP.1564.TO
# 193                        None             SST  1960  SP.POP.65UP.TO
# 194                        None             SST  1960     SP.POP.TOTL
# 195                        None             SAS  1960     IT.CEL.SETS
# 196                        None             SAS  1960  SP.POP.0014.TO
# 197                        None             SAS  1960  SP.POP.1564.TO
# 198                        None             SAS  1960  SP.POP.65UP.TO
# 199                        None             SAS  1960     SP.POP.TOTL
# 200                        None             TSA  1960     IT.CEL.SETS
# 201                        None             TSA  1960  SP.POP.0014.TO
# 202                        None             TSA  1960  SP.POP.1564.TO
# 203                        None             TSA  1960  SP.POP.65UP.TO
# 204                        None             TSA  1960     SP.POP.TOTL
# 205                        None             SSF  1960     IT.CEL.SETS
# 206                        None             SSF  1960  SP.POP.0014.TO
# 207                        None             SSF  1960  SP.POP.1564.TO
# 208                        None             SSF  1960  SP.POP.65UP.TO
# 209                        None             SSF  1960     SP.POP.TOTL
# 210                        None             SSA  1960     IT.CEL.SETS
# 211                        None             SSA  1960  SP.POP.0014.TO
# 212                        None             SSA  1960  SP.POP.1564.TO
# 213                        None             SSA  1960  SP.POP.65UP.TO
# 214                        None             SSA  1960     SP.POP.TOTL
# 215                        None             TSS  1960     IT.CEL.SETS
# 216                        None             TSS  1960  SP.POP.0014.TO
# 217                        None             TSS  1960  SP.POP.1564.TO
# 218                        None             TSS  1960  SP.POP.65UP.TO
# 219                        None             TSS  1960     SP.POP.TOTL
# 220                        None             UMC  1960     IT.CEL.SETS
# 221                        None             UMC  1960  SP.POP.0014.TO
# 222                        None             UMC  1960  SP.POP.1564.TO
# 223                        None             UMC  1960  SP.POP.65UP.TO
# 224                        None             UMC  1960     SP.POP.TOTL
# 225                        None             WLD  1960     IT.CEL.SETS
# 226                        None             WLD  1960  SP.POP.0014.TO
# 227                        None             WLD  1960  SP.POP.1564.TO
# 228                        None             WLD  1960  SP.POP.65UP.TO
# 229                        None             WLD  1960     SP.POP.TOTL
# 230                  South Asia             AFG  1960     IT.CEL.SETS
# 231                  South Asia             AFG  1960  SP.POP.0014.TO
# 232                  South Asia             AFG  1960  SP.POP.1564.TO
# 233                  South Asia             AFG  1960  SP.POP.65UP.TO
# 234                  South Asia             AFG  1960     SP.POP.TOTL
# 235       Europe & Central Asia             ALB  1960     IT.CEL.SETS
# 236       Europe & Central Asia             ALB  1960  SP.POP.0014.TO
# 237       Europe & Central Asia             ALB  1960  SP.POP.1564.TO
# 238       Europe & Central Asia             ALB  1960  SP.POP.65UP.TO
# 239       Europe & Central Asia             ALB  1960     SP.POP.TOTL
# 240  Middle East & North Africa             DZA  1960     IT.CEL.SETS
# 241  Middle East & North Africa             DZA  1960  SP.POP.0014.TO
# 242  Middle East & North Africa             DZA  1960  SP.POP.1564.TO
# 243  Middle East & North Africa             DZA  1960  SP.POP.65UP.TO
# 244  Middle East & North Africa             DZA  1960     SP.POP.TOTL
# 245         East Asia & Pacific             ASM  1960     IT.CEL.SETS
# 246         East Asia & Pacific             ASM  1960     SP.POP.TOTL
# 247       Europe & Central Asia             AND  1960     IT.CEL.SETS
# 248       Europe & Central Asia             AND  1960     SP.POP.TOTL
# 249          Sub-Saharan Africa             AGO  1960     IT.CEL.SETS
# 250          Sub-Saharan Africa             AGO  1960  SP.POP.0014.TO
# 251          Sub-Saharan Africa             AGO  1960  SP.POP.1564.TO
# 252          Sub-Saharan Africa             AGO  1960  SP.POP.65UP.TO
# 253          Sub-Saharan Africa             AGO  1960     SP.POP.TOTL
# 254   Latin America & Caribbean             ATG  1960     IT.CEL.SETS
# 255   Latin America & Caribbean             ATG  1960  SP.POP.0014.TO
# 256   Latin America & Caribbean             ATG  1960  SP.POP.1564.TO
# 257   Latin America & Caribbean             ATG  1960  SP.POP.65UP.TO
# 258   Latin America & Caribbean             ATG  1960     SP.POP.TOTL
# 354   Latin America & Caribbean             BRA  1960  SP.POP.65UP.TO
# 355   Latin America & Caribbean             BRA  1960     SP.POP.TOTL
# 356   Latin America & Caribbean             VGB  1960     IT.CEL.SETS
# 357   Latin America & Caribbean             VGB  1960     SP.POP.TOTL
# 358         East Asia & Pacific             BRN  1960     IT.CEL.SETS
# 359         East Asia & Pacific             BRN  1960  SP.POP.0014.TO
# 360         East Asia & Pacific             BRN  1960  SP.POP.1564.TO
# 361         East Asia & Pacific             BRN  1960  SP.POP.65UP.TO
# 362         East Asia & Pacific             BRN  1960     SP.POP.TOTL
# 363       Europe & Central Asia             BGR  1960     IT.CEL.SETS
# 364       Europe & Central Asia             BGR  1960  SP.POP.0014.TO
# 365       Europe & Central Asia             BGR  1960  SP.POP.1564.TO
# 366       Europe & Central Asia             BGR  1960  SP.POP.65UP.TO
# 367       Europe & Central Asia             BGR  1960     SP.POP.TOTL
# 368          Sub-Saharan Africa             BFA  1960     IT.CEL.SETS
# 369          Sub-Saharan Africa             BFA  1960  SP.POP.0014.TO
# 370          Sub-Saharan Africa             BFA  1960  SP.POP.1564.TO
# 371          Sub-Saharan Africa             BFA  1960  SP.POP.65UP.TO
# 372          Sub-Saharan Africa             BFA  1960     SP.POP.TOTL
# 373          Sub-Saharan Africa             BDI  1960     IT.CEL.SETS
# 374          Sub-Saharan Africa             BDI  1960  SP.POP.0014.TO
# 375          Sub-Saharan Africa             BDI  1960  SP.POP.1564.TO
# 376          Sub-Saharan Africa             BDI  1960  SP.POP.65UP.TO
# 377          Sub-Saharan Africa             BDI  1960     SP.POP.TOTL
# 378          Sub-Saharan Africa             CPV  1960     IT.CEL.SETS
# 379          Sub-Saharan Africa             CPV  1960  SP.POP.0014.TO
# 380          Sub-Saharan Africa             CPV  1960  SP.POP.1564.TO
# 381          Sub-Saharan Africa             CPV  1960  SP.POP.65UP.TO
# 382          Sub-Saharan Africa             CPV  1960     SP.POP.TOTL
# 383         East Asia & Pacific             KHM  1960     IT.CEL.SETS
# 384         East Asia & Pacific             KHM  1960  SP.POP.0014.TO
# 385         East Asia & Pacific             KHM  1960  SP.POP.1564.TO
# 386         East Asia & Pacific             KHM  1960  SP.POP.65UP.TO
# 387         East Asia & Pacific             KHM  1960     SP.POP.TOTL
# 388          Sub-Saharan Africa             CMR  1960     IT.CEL.SETS
# 389          Sub-Saharan Africa             CMR  1960  SP.POP.0014.TO
# 390          Sub-Saharan Africa             CMR  1960  SP.POP.1564.TO
# 391          Sub-Saharan Africa             CMR  1960  SP.POP.65UP.TO
# 392          Sub-Saharan Africa             CMR  1960     SP.POP.TOTL
# 393               North America             CAN  1960     IT.CEL.SETS
# 394               North America             CAN  1960  SP.POP.0014.TO
# 395               North America             CAN  1960  SP.POP.1564.TO
# 396               North America             CAN  1960  SP.POP.65UP.TO
# 397               North America             CAN  1960     SP.POP.TOTL
# 398   Latin America & Caribbean             CYM  1960     IT.CEL.SETS
# 399   Latin America & Caribbean             CYM  1960     SP.POP.TOTL
# 400          Sub-Saharan Africa             CAF  1960     IT.CEL.SETS
# 401          Sub-Saharan Africa             CAF  1960  SP.POP.0014.TO
# 402          Sub-Saharan Africa             CAF  1960  SP.POP.1564.TO
# 403          Sub-Saharan Africa             CAF  1960  SP.POP.65UP.TO
# 404          Sub-Saharan Africa             CAF  1960     SP.POP.TOTL
# 405          Sub-Saharan Africa             TCD  1960     IT.CEL.SETS
# 406          Sub-Saharan Africa             TCD  1960  SP.POP.0014.TO
# 407          Sub-Saharan Africa             TCD  1960  SP.POP.1564.TO
# 408          Sub-Saharan Africa             TCD  1960  SP.POP.65UP.TO
# 409          Sub-Saharan Africa             TCD  1960     SP.POP.TOTL
# 410   Latin America & Caribbean             CHL  1960     IT.CEL.SETS
# 411   Latin America & Caribbean             CHL  1960  SP.POP.0014.TO
# 412   Latin America & Caribbean             CHL  1960  SP.POP.1564.TO
# 413   Latin America & Caribbean             CHL  1960  SP.POP.65UP.TO
# 414   Latin America & Caribbean             CHL  1960     SP.POP.TOTL
# 415         East Asia & Pacific             CHN  1960     IT.CEL.SETS
# 416         East Asia & Pacific             CHN  1960  SP.POP.0014.TO
# 417         East Asia & Pacific             CHN  1960  SP.POP.1564.TO
# 418         East Asia & Pacific             CHN  1960  SP.POP.65UP.TO
# 419         East Asia & Pacific             CHN  1960     SP.POP.TOTL
# 420   Latin America & Caribbean             COL  1960     IT.CEL.SETS
# 421   Latin America & Caribbean             COL  1960  SP.POP.0014.TO
# 422   Latin America & Caribbean             COL  1960  SP.POP.1564.TO
# 423   Latin America & Caribbean             COL  1960  SP.POP.65UP.TO
# 424   Latin America & Caribbean             COL  1960     SP.POP.TOTL
# 425          Sub-Saharan Africa             COM  1960     IT.CEL.SETS
# 426          Sub-Saharan Africa             COM  1960  SP.POP.0014.TO
# 427          Sub-Saharan Africa             COM  1960  SP.POP.1564.TO
# 428          Sub-Saharan Africa             COM  1960  SP.POP.65UP.TO
# 429          Sub-Saharan Africa             COM  1960     SP.POP.TOTL
# 430          Sub-Saharan Africa             COD  1960     IT.CEL.SETS
# 431          Sub-Saharan Africa             COD  1960  SP.POP.0014.TO
# 432          Sub-Saharan Africa             COD  1960  SP.POP.1564.TO
# 433          Sub-Saharan Africa             COD  1960  SP.POP.65UP.TO
# 434          Sub-Saharan Africa             COD  1960     SP.POP.TOTL
# 435          Sub-Saharan Africa             COG  1960     IT.CEL.SETS
# 436          Sub-Saharan Africa             COG  1960  SP.POP.0014.TO
# 437          Sub-Saharan Africa             COG  1960  SP.POP.1564.TO
# 438          Sub-Saharan Africa             COG  1960  SP.POP.65UP.TO
# 439          Sub-Saharan Africa             COG  1960     SP.POP.TOTL
# 440   Latin America & Caribbean             CRI  1960     IT.CEL.SETS
# 441   Latin America & Caribbean             CRI  1960  SP.POP.0014.TO
# 442   Latin America & Caribbean             CRI  1960  SP.POP.1564.TO
# 443   Latin America & Caribbean             CRI  1960  SP.POP.65UP.TO
# 444   Latin America & Caribbean             CRI  1960     SP.POP.TOTL
# 445          Sub-Saharan Africa             CIV  1960     IT.CEL.SETS
# 446          Sub-Saharan Africa             CIV  1960  SP.POP.0014.TO
# 447          Sub-Saharan Africa             CIV  1960  SP.POP.1564.TO
# 448          Sub-Saharan Africa             CIV  1960  SP.POP.65UP.TO
# 449          Sub-Saharan Africa             CIV  1960     SP.POP.TOTL
# 450       Europe & Central Asia             HRV  1960     IT.CEL.SETS
# 451       Europe & Central Asia             HRV  1960  SP.POP.0014.TO
# 452       Europe & Central Asia             HRV  1960  SP.POP.1564.TO
# 453       Europe & Central Asia             HRV  1960  SP.POP.65UP.TO
# 454       Europe & Central Asia             HRV  1960     SP.POP.TOTL
# 455   Latin America & Caribbean             CUB  1960     IT.CEL.SETS
# 456   Latin America & Caribbean             CUB  1960  SP.POP.0014.TO
# 457   Latin America & Caribbean             CUB  1960  SP.POP.1564.TO
# 458   Latin America & Caribbean             CUB  1960  SP.POP.65UP.TO
# 459   Latin America & Caribbean             CUB  1960     SP.POP.TOTL
# 460   Latin America & Caribbean             CUW  1960  SP.POP.0014.TO
# 461   Latin America & Caribbean             CUW  1960  SP.POP.1564.TO
# 462   Latin America & Caribbean             CUW  1960  SP.POP.65UP.TO
# 463   Latin America & Caribbean             CUW  1960     SP.POP.TOTL
# 464       Europe & Central Asia             CYP  1960     IT.CEL.SETS
# 465       Europe & Central Asia             CYP  1960  SP.POP.0014.TO
# 466       Europe & Central Asia             CYP  1960  SP.POP.1564.TO
# 467       Europe & Central Asia             CYP  1960  SP.POP.65UP.TO
# 468       Europe & Central Asia             CYP  1960     SP.POP.TOTL
# 469       Europe & Central Asia             CZE  1960     IT.CEL.SETS
# 470       Europe & Central Asia             CZE  1960  SP.POP.0014.TO
# 471       Europe & Central Asia             CZE  1960  SP.POP.1564.TO
# 472       Europe & Central Asia             CZE  1960  SP.POP.65UP.TO
# 473       Europe & Central Asia             CZE  1960     SP.POP.TOTL
# 474       Europe & Central Asia             DNK  1960     IT.CEL.SETS
# 475       Europe & Central Asia             DNK  1960  SP.POP.0014.TO
# 476       Europe & Central Asia             DNK  1960  SP.POP.1564.TO
# 477       Europe & Central Asia             DNK  1960  SP.POP.65UP.TO
# 478       Europe & Central Asia             DNK  1960     SP.POP.TOTL
# 479  Middle East & North Africa             DJI  1960     IT.CEL.SETS
# 480  Middle East & North Africa             DJI  1960  SP.POP.0014.TO
# 481  Middle East & North Africa             DJI  1960  SP.POP.1564.TO
# 482  Middle East & North Africa             DJI  1960  SP.POP.65UP.TO
# 483  Middle East & North Africa             DJI  1960     SP.POP.TOTL
# 484   Latin America & Caribbean             DMA  1960     IT.CEL.SETS
# 485   Latin America & Caribbean             DMA  1960     SP.POP.TOTL
# 486   Latin America & Caribbean             DOM  1960     IT.CEL.SETS
# 487   Latin America & Caribbean             DOM  1960  SP.POP.0014.TO
# 488   Latin America & Caribbean             DOM  1960  SP.POP.1564.TO
# 489   Latin America & Caribbean             DOM  1960  SP.POP.65UP.TO
# 490   Latin America & Caribbean             DOM  1960     SP.POP.TOTL
# 491   Latin America & Caribbean             ECU  1960     IT.CEL.SETS
# 492   Latin America & Caribbean             ECU  1960  SP.POP.0014.TO
# 493   Latin America & Caribbean             ECU  1960  SP.POP.1564.TO
# 494   Latin America & Caribbean             ECU  1960  SP.POP.65UP.TO
# 495   Latin America & Caribbean             ECU  1960     SP.POP.TOTL
# 496  Middle East & North Africa             EGY  1960     IT.CEL.SETS
# 497  Middle East & North Africa             EGY  1960  SP.POP.0014.TO
# 498  Middle East & North Africa             EGY  1960  SP.POP.1564.TO
# 499  Middle East & North Africa             EGY  1960  SP.POP.65UP.TO
# 500  Middle East & North Africa             EGY  1960     SP.POP.TOTL
# 501   Latin America & Caribbean             SLV  1960     IT.CEL.SETS
# 502   Latin America & Caribbean             SLV  1960  SP.POP.0014.TO
# 503   Latin America & Caribbean             SLV  1960  SP.POP.1564.TO
# 504   Latin America & Caribbean             SLV  1960  SP.POP.65UP.TO
# 505   Latin America & Caribbean             SLV  1960     SP.POP.TOTL
# 506          Sub-Saharan Africa             GNQ  1960     IT.CEL.SETS
# 507          Sub-Saharan Africa             GNQ  1960  SP.POP.0014.TO
# 508          Sub-Saharan Africa             GNQ  1960  SP.POP.1564.TO
# 509          Sub-Saharan Africa             GNQ  1960  SP.POP.65UP.TO
# 510          Sub-Saharan Africa             GNQ  1960     SP.POP.TOTL
# 511          Sub-Saharan Africa             ERI  1960     IT.CEL.SETS
# 512          Sub-Saharan Africa             ERI  1960  SP.POP.0014.TO
# 513          Sub-Saharan Africa             ERI  1960  SP.POP.1564.TO
# 514          Sub-Saharan Africa             ERI  1960  SP.POP.65UP.TO
# 515          Sub-Saharan Africa             ERI  1960     SP.POP.TOTL
# 516       Europe & Central Asia             EST  1960     IT.CEL.SETS
# 517       Europe & Central Asia             EST  1960  SP.POP.0014.TO
# 518       Europe & Central Asia             EST  1960  SP.POP.1564.TO
# 519       Europe & Central Asia             EST  1960  SP.POP.65UP.TO
# 520       Europe & Central Asia             EST  1960     SP.POP.TOTL
# 521          Sub-Saharan Africa             ETH  1960     IT.CEL.SETS
# 522          Sub-Saharan Africa             ETH  1960  SP.POP.0014.TO
# 523          Sub-Saharan Africa             ETH  1960  SP.POP.1564.TO
# 524          Sub-Saharan Africa             ETH  1960  SP.POP.65UP.TO
# 525          Sub-Saharan Africa             ETH  1960     SP.POP.TOTL
# 526       Europe & Central Asia             FRO  1960     IT.CEL.SETS
# 527       Europe & Central Asia             FRO  1960     SP.POP.TOTL
# 528         East Asia & Pacific             FJI  1960     IT.CEL.SETS
# 529         East Asia & Pacific             FJI  1960  SP.POP.0014.TO
# 530         East Asia & Pacific             FJI  1960  SP.POP.1564.TO
# 531         East Asia & Pacific             FJI  1960  SP.POP.65UP.TO
# 532         East Asia & Pacific             FJI  1960     SP.POP.TOTL
# 533       Europe & Central Asia             FIN  1960     IT.CEL.SETS
# 534       Europe & Central Asia             FIN  1960  SP.POP.0014.TO
# 535       Europe & Central Asia             FIN  1960  SP.POP.1564.TO
# 536       Europe & Central Asia             FIN  1960  SP.POP.65UP.TO
# 537       Europe & Central Asia             FIN  1960     SP.POP.TOTL
# 538       Europe & Central Asia             FRA  1960     IT.CEL.SETS
# 539       Europe & Central Asia             FRA  1960  SP.POP.0014.TO
# 540       Europe & Central Asia             FRA  1960  SP.POP.1564.TO
# 541       Europe & Central Asia             FRA  1960  SP.POP.65UP.TO
# 542       Europe & Central Asia             FRA  1960     SP.POP.TOTL
# 543         East Asia & Pacific             PYF  1960     IT.CEL.SETS
# 544         East Asia & Pacific             PYF  1960  SP.POP.0014.TO
# 545         East Asia & Pacific             PYF  1960  SP.POP.1564.TO
# 546         East Asia & Pacific             PYF  1960  SP.POP.65UP.TO
# 547         East Asia & Pacific             PYF  1960     SP.POP.TOTL
# 548          Sub-Saharan Africa             GAB  1960     IT.CEL.SETS
# 549          Sub-Saharan Africa             GAB  1960  SP.POP.0014.TO
# 550          Sub-Saharan Africa             GAB  1960  SP.POP.1564.TO
# 551          Sub-Saharan Africa             GAB  1960  SP.POP.65UP.TO
# 552          Sub-Saharan Africa             GAB  1960     SP.POP.TOTL
# 553          Sub-Saharan Africa             GMB  1960     IT.CEL.SETS
# 554          Sub-Saharan Africa             GMB  1960  SP.POP.0014.TO
# 555          Sub-Saharan Africa             GMB  1960  SP.POP.1564.TO
# 556          Sub-Saharan Africa             GMB  1960  SP.POP.65UP.TO
# 557          Sub-Saharan Africa             GMB  1960     SP.POP.TOTL
# 558       Europe & Central Asia             GEO  1960     IT.CEL.SETS
# 559       Europe & Central Asia             GEO  1960  SP.POP.0014.TO
# 560       Europe & Central Asia             GEO  1960  SP.POP.1564.TO
# 561       Europe & Central Asia             GEO  1960  SP.POP.65UP.TO
# 562       Europe & Central Asia             GEO  1960     SP.POP.TOTL
# 563       Europe & Central Asia             DEU  1960     IT.CEL.SETS
# 564       Europe & Central Asia             DEU  1960  SP.POP.0014.TO
# 565       Europe & Central Asia             DEU  1960  SP.POP.1564.TO
# 566       Europe & Central Asia             DEU  1960  SP.POP.65UP.TO
# 567       Europe & Central Asia             DEU  1960     SP.POP.TOTL
# 568          Sub-Saharan Africa             GHA  1960     IT.CEL.SETS
# 569          Sub-Saharan Africa             GHA  1960  SP.POP.0014.TO
# 570          Sub-Saharan Africa             GHA  1960  SP.POP.1564.TO
# 571          Sub-Saharan Africa             GHA  1960  SP.POP.65UP.TO
# 572          Sub-Saharan Africa             GHA  1960     SP.POP.TOTL
# 573       Europe & Central Asia             GIB  1960     IT.CEL.SETS
# 574       Europe & Central Asia             GIB  1960     SP.POP.TOTL
# 575       Europe & Central Asia             GRC  1960     IT.CEL.SETS
# 576       Europe & Central Asia             GRC  1960  SP.POP.0014.TO
# 577       Europe & Central Asia             GRC  1960  SP.POP.1564.TO
# 578       Europe & Central Asia             GRC  1960  SP.POP.65UP.TO
# 579       Europe & Central Asia             GRC  1960     SP.POP.TOTL
# 580       Europe & Central Asia             GRL  1960     IT.CEL.SETS
# 581       Europe & Central Asia             GRL  1960     SP.POP.TOTL
# 582   Latin America & Caribbean             GRD  1960     IT.CEL.SETS
# 583   Latin America & Caribbean             GRD  1960  SP.POP.0014.TO
# 584   Latin America & Caribbean             GRD  1960  SP.POP.1564.TO
# 585   Latin America & Caribbean             GRD  1960  SP.POP.65UP.TO
# 586   Latin America & Caribbean             GRD  1960     SP.POP.TOTL
# 587         East Asia & Pacific             GUM  1960     IT.CEL.SETS
# 588         East Asia & Pacific             GUM  1960  SP.POP.0014.TO
# 589         East Asia & Pacific             GUM  1960  SP.POP.1564.TO
# 590         East Asia & Pacific             GUM  1960  SP.POP.65UP.TO
# 591         East Asia & Pacific             GUM  1960     SP.POP.TOTL
# 592   Latin America & Caribbean             GTM  1960     IT.CEL.SETS
# 593   Latin America & Caribbean             GTM  1960  SP.POP.0014.TO
# 594   Latin America & Caribbean             GTM  1960  SP.POP.1564.TO
# 595   Latin America & Caribbean             GTM  1960  SP.POP.65UP.TO
# 596   Latin America & Caribbean             GTM  1960     SP.POP.TOTL
# 597          Sub-Saharan Africa             GIN  1960     IT.CEL.SETS
# 598          Sub-Saharan Africa             GIN  1960  SP.POP.0014.TO
# 599          Sub-Saharan Africa             GIN  1960  SP.POP.1564.TO
# 600          Sub-Saharan Africa             GIN  1960  SP.POP.65UP.TO
# 601          Sub-Saharan Africa             GIN  1960     SP.POP.TOTL
# 602          Sub-Saharan Africa             GNB  1960     IT.CEL.SETS
# 603          Sub-Saharan Africa             GNB  1960  SP.POP.0014.TO
# 604          Sub-Saharan Africa             GNB  1960  SP.POP.1564.TO
# 605          Sub-Saharan Africa             GNB  1960  SP.POP.65UP.TO
# 606          Sub-Saharan Africa             GNB  1960     SP.POP.TOTL
# 607   Latin America & Caribbean             GUY  1960     IT.CEL.SETS
# 608   Latin America & Caribbean             GUY  1960  SP.POP.0014.TO
# 609   Latin America & Caribbean             GUY  1960  SP.POP.1564.TO
# 610   Latin America & Caribbean             GUY  1960  SP.POP.65UP.TO
# 611   Latin America & Caribbean             GUY  1960     SP.POP.TOTL
# 612   Latin America & Caribbean             HTI  1960     IT.CEL.SETS
# 613   Latin America & Caribbean             HTI  1960  SP.POP.0014.TO
# 614   Latin America & Caribbean             HTI  1960  SP.POP.1564.TO
# 615   Latin America & Caribbean             HTI  1960  SP.POP.65UP.TO
# 616   Latin America & Caribbean             HTI  1960     SP.POP.TOTL
# 617   Latin America & Caribbean             HND  1960     IT.CEL.SETS
# 618   Latin America & Caribbean             HND  1960  SP.POP.0014.TO
# 619   Latin America & Caribbean             HND  1960  SP.POP.1564.TO
# 620   Latin America & Caribbean             HND  1960  SP.POP.65UP.TO
# 621   Latin America & Caribbean             HND  1960     SP.POP.TOTL
# 622         East Asia & Pacific             HKG  1960     IT.CEL.SETS
# 623         East Asia & Pacific             HKG  1960  SP.POP.0014.TO
# 624         East Asia & Pacific             HKG  1960  SP.POP.1564.TO
# 625         East Asia & Pacific             HKG  1960  SP.POP.65UP.TO
# 626         East Asia & Pacific             HKG  1960     SP.POP.TOTL
# 627       Europe & Central Asia             HUN  1960     IT.CEL.SETS
# 628       Europe & Central Asia             HUN  1960  SP.POP.0014.TO
# 629       Europe & Central Asia             HUN  1960  SP.POP.1564.TO
# 630       Europe & Central Asia             HUN  1960  SP.POP.65UP.TO
# 631       Europe & Central Asia             HUN  1960     SP.POP.TOTL
# 632       Europe & Central Asia             ISL  1960     IT.CEL.SETS
# 633       Europe & Central Asia             ISL  1960  SP.POP.0014.TO
# 634       Europe & Central Asia             ISL  1960  SP.POP.1564.TO
# 635       Europe & Central Asia             ISL  1960  SP.POP.65UP.TO
# 636       Europe & Central Asia             ISL  1960     SP.POP.TOTL
# 637                  South Asia             IND  1960     IT.CEL.SETS
# 638                  South Asia             IND  1960  SP.POP.0014.TO
# 639                  South Asia             IND  1960  SP.POP.1564.TO
# 640                  South Asia             IND  1960  SP.POP.65UP.TO
# 641                  South Asia             IND  1960     SP.POP.TOTL
# 642         East Asia & Pacific             IDN  1960     IT.CEL.SETS
# 643         East Asia & Pacific             IDN  1960  SP.POP.0014.TO
# 644         East Asia & Pacific             IDN  1960  SP.POP.1564.TO
# 645         East Asia & Pacific             IDN  1960  SP.POP.65UP.TO
# 646         East Asia & Pacific             IDN  1960     SP.POP.TOTL
# 647  Middle East & North Africa             IRN  1960     IT.CEL.SETS
# 648  Middle East & North Africa             IRN  1960  SP.POP.0014.TO
# 649  Middle East & North Africa             IRN  1960  SP.POP.1564.TO
# 650  Middle East & North Africa             IRN  1960  SP.POP.65UP.TO
# 651  Middle East & North Africa             IRN  1960     SP.POP.TOTL
# 652  Middle East & North Africa             IRQ  1960     IT.CEL.SETS
# 653  Middle East & North Africa             IRQ  1960  SP.POP.0014.TO
# 654  Middle East & North Africa             IRQ  1960  SP.POP.1564.TO
# 655  Middle East & North Africa             IRQ  1960  SP.POP.65UP.TO
# ...
# 305     8.794200e+04
# 306     1.272670e+05
# 307     1.573000e+04
# 308     2.309390e+05
# 309     0.000000e+00
# 310     2.362149e+06
# 311     5.150065e+06
# 312     6.857860e+05
# 313     8.198000e+06
# 314     0.000000e+00
# 315     2.152022e+06
# 316     5.914589e+06
# 317     1.086878e+06
# 318     9.153489e+06
# 319     0.000000e+00
# 320     4.168400e+04
# 321     4.656100e+04
# 322     3.819000e+03
# 323     9.206400e+04
# 324     0.000000e+00
# 325     9.369530e+05
# 326     1.372568e+06
# 327     1.221010e+05
# 328     2.431622e+06
# 329     0.000000e+00
# 330     4.440000e+04
# 331     0.000000e+00
# 332     9.400400e+04
# 333     1.240160e+05
# 334     5.268000e+03
# 335     2.232880e+05
# 336     0.000000e+00
# 337     1.563057e+06
# 338     1.960654e+06
# 339     1.697380e+05
# 340     3.693449e+06
# 341     0.000000e+00
# 342     1.225445e+06
# 343     1.889173e+06
# 344     1.110500e+05
# 345     3.225668e+06
# 346     0.000000e+00
# 347     2.396120e+05
# 348     2.640860e+05
# 349     2.085400e+04
# 350     5.245520e+05
# 351     0.000000e+00
# 352     3.115154e+07
# 353     3.878113e+07
# 354     2.274892e+06
# 355     7.220755e+07
# 356     0.000000e+00
# 357     8.033000e+03
# 358     0.000000e+00
# 359     3.553500e+04
# 360     4.299000e+04
# 361     3.220000e+03
# %%
showDF(regionalPivot.orderBy('region', 'year'), limitRows=100)
# Out:
#                  region  year   IT.CEL.SETS   IT.NET.BBND  SP.POP.0014.TO  \
# 0                  None  1960  0.000000e+00           NaN    1.052918e+10
# 1                  None  1961           NaN           NaN    1.072883e+10
# 2                  None  1962           NaN           NaN    1.099508e+10
# 3                  None  1963           NaN           NaN    1.130876e+10
# 4                  None  1964           NaN           NaN    1.159883e+10
# 5                  None  1965  0.000000e+00           NaN    1.186024e+10
# 6                  None  1966           NaN           NaN    1.216311e+10
# 7                  None  1967           NaN           NaN    1.241838e+10
# 8                  None  1968           NaN           NaN    1.264760e+10
# 9                  None  1969           NaN           NaN    1.288063e+10
# 10                 None  1970  0.000000e+00           NaN    1.312208e+10
# 11                 None  1971           NaN           NaN    1.339224e+10
# 12                 None  1972           NaN           NaN    1.365141e+10
# 13                 None  1973           NaN           NaN    1.389953e+10
# 14                 None  1974           NaN           NaN    1.412763e+10
# 15                 None  1975  0.000000e+00           NaN    1.432417e+10
# 16                 None  1976  0.000000e+00           NaN    1.451799e+10
# 17                 None  1977  0.000000e+00           NaN    1.468237e+10
# 18                 None  1978  0.000000e+00           NaN    1.482777e+10
# 19                 None  1979  0.000000e+00           NaN    1.496503e+10
# 20                 None  1980  1.643740e+05           NaN    1.509894e+10
# 21                 None  1981  3.948430e+05           NaN    1.524631e+10
# 22                 None  1982  6.097410e+05           NaN    1.540788e+10
# 23                 None  1983  8.811210e+05           NaN    1.557283e+10
# 24                 None  1984  1.796544e+06           NaN    1.573395e+10
# 25                 None  1985  4.108062e+06           NaN    1.589767e+10
# 26                 None  1986  7.968225e+06           NaN    1.612344e+10
# 27                 None  1987  1.400003e+07           NaN    1.634716e+10
# 28                 None  1988  2.382929e+07           NaN    1.656733e+10
# 29                 None  1989  4.035322e+07           NaN    1.677947e+10
# 30                 None  1990  6.197029e+07           NaN    1.698502e+10
# 31                 None  1991  9.094891e+07           NaN    1.722226e+10
# 32                 None  1992  1.315735e+08           NaN    1.740833e+10
# 33                 None  1993  1.976234e+08           NaN    1.756395e+10
# 34                 None  1994  3.285952e+08           NaN    1.770281e+10
# 35                 None  1995  5.479371e+08           NaN    1.783435e+10
# 36                 None  1996  8.897939e+08           NaN    1.791217e+10
# 37                 None  1997  1.370814e+09           NaN    1.800713e+10
# 38                 None  1998  2.084697e+09  8.459000e+05    1.809512e+10
# 39                 None  1999  3.340473e+09  3.336286e+06    1.814662e+10
# 40                 None  2000  5.256610e+09  6.395584e+07    1.815287e+10
# 41                 None  2001  7.129602e+09  1.901302e+08    1.817975e+10
# 42                 None  2002  8.931245e+09  3.736333e+08    1.816684e+10
# 43                 None  2003  1.118402e+10  6.268839e+08    1.813193e+10
# 44                 None  2004  1.441172e+10  1.021665e+09    1.810561e+10
# 45                 None  2005  1.862753e+10  1.465743e+09    1.810565e+10
# 46                 None  2006  2.378235e+10  1.959475e+09    1.815655e+10
# 47                 None  2007  2.977887e+10  2.494826e+09    1.822321e+10
') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population') \
    .select(col('region')
            , col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('../output/RegionalStats', mode='overwrite', header='true')

# %% [markdown]
# ## Short Exercise
#
# Becky finds the regional metrics interesting, but she wants to look at these metrics at a country level for each year.  Can you adapt the regional pivot that we computed earlier to get the metrics for each year and country ?

# %%
#Your solution here
countryIndicators = indicatorsDF.join(countryDimFinal
                                       , indicatorsDF.wb_country_code == countryDim.wb_country_code
                                       , "inner") \
    .select(indicatorsDF.wb_country_code,
            countryDim.country_iso_code,
            countryDim.country_name,
            indicatorsDF.year,
            indicatorsDF.indicator_code,
            indicatorsDF.indicator_value)

showDF(countryIndicators)
# Out:
#    wb_country_code country_iso_code                    country_name  year  \
# 0              ARB               1A                      Arab World  1960
# 1              ARB               1A                      Arab World  1960
# 2              ARB               1A                      Arab World  1960
# 3              ARB               1A                      Arab World  1960
# 4              ARB               1A                      Arab World  1960
# 5              CSS               S3          Caribbean small states  1960
# 6              CSS               S3          Caribbean small states  1960
# 7              CSS               S3          Caribbean small states  1960
# 8              CSS               S3          Caribbean small states  1960
# 9              CSS               S3          Caribbean small states  1960
# 10             CEB               B8  Central Europe and the Baltics  1960
# 11             CEB               B8  Central Europe and the Baltics  1960
# 12             CEB               B8  Central Europe and the Baltics  1960
# 13             CEB               B8  Central Europe and the Baltics  1960
# 14             CEB               B8  Central Europe and the Baltics  1960
# 15             EAR               V2      Early-demographic dividend  1960
# 16             EAR               V2      Early-demographic dividend  1960
# 17             EAR               V2      Early-demographic dividend  1960
# 18             EAR               V2      Early-demographic dividend  1960
# 19             EAR               V2      Early-demographic dividend  1960
#
#     indicator_code  indicator_value
# 0      IT.CEL.SETS              0.0
# 1   SP.POP.0014.TO       40064255.0
# 2   SP.POP.1564.TO       49179481.0
# 3   SP.POP.65UP.TO        3247196.0
# 4      SP.POP.TOTL       92490932.0
# 5      IT.CEL.SETS              0.0
# 6   SP.POP.0014.TO        1766884.0
# 7   SP.POP.1564.TO        2151060.0
# 8   SP.POP.65UP.TO         169157.0
# 9      SP.POP.TOTL        4198307.0
# 10     IT.CEL.SETS              0.0
# 11  SP.POP.0014.TO       26671149.0
# 12  SP.POP.1564.TO       58135954.0
# 13  SP.POP.65UP.TO        6594481.0
# 14     SP.POP.TOTL       91401583.0
# 15     IT.CEL.SETS              0.0
# 16  SP.POP.0014.TO      403027249.0
# 17  SP.POP.1564.TO      543753940.0
# 18  SP.POP.65UP.TO       32506217.0
# 19     SP.POP.TOTL      979287407.0

# %%
countryPivot = countryIndicators.groupBy('country_iso_code', 'country_name', 'year') \
                                .pivot('indicator_code').sum('indicator_value')

showDF(countryPivot.orderBy('year'))
# Out:
#    country_iso_code                                  country_name  year  \
# 0                LU                                    Luxembourg  1960
# 1                UG                                        Uganda  1960
# 2                GH                                         Ghana  1960
# 3                HK                          Hong Kong SAR, China  1960
# 4                XM                                    Low income  1960
# 5                DZ                                       Algeria  1960
# 6                DJ                                      Djibouti  1960
# 7                PE                                          Peru  1960
# 8                SB                               Solomon Islands  1960
# 9                BB                                      Barbados  1960
# 10               IL                                        Israel  1960
# 11               XL  Least developed countries: UN classification  1960
# 12               EC                                       Ecuador  1960
# 13               TO                                         Tonga  1960
# 14               ZW                                      Zimbabwe  1960
# 15               AR                                     Argentina  1960
# 16               GD                                       Grenada  1960
# 17               MV                                      Maldives  1960
# 18               HU                                       Hungary  1960
# 19               NZ                                   New Zealand  1960
#
#     IT.CEL.SETS  IT.NET.BBND  SP.POP.0014.TO  SP.POP.1564.TO  SP.POP.65UP.TO  \
# 0           0.0          NaN         66505.0        213480.0         33985.0
# 1           0.0          NaN       3115941.0       3495381.0        176892.0
# 2           0.0          NaN       2948877.0       3544333.0        159077.0
# 3           0.0          NaN       1248491.0       1742762.0         84352.0
# 4           0.0          NaN      65862606.0      84444524.0       4363033.0
# 5           0.0          NaN       4954926.0       5811610.0        358352.0
# 6           0.0          NaN         36263.0         45437.0          1936.0
# 7           0.0          NaN       4392114.0       5323598.0        345803.0
# 8           0.0          NaN         50205.0         64520.0          3141.0
# 9           0.0          NaN         87942.0        127267.0         15730.0
# 10          NaN          NaN        770792.0       1244654.0         98573.0
# 11          0.0          NaN     102797862.0     131131391.0       6806839.0
# 12          0.0          NaN       1972927.0       2359115.0        213508.0
# 13          0.0          NaN         27970.0         31527.0          2104.0
# 14          0.0          NaN       1697006.0       1924276.0        126087.0
# 15          0.0          NaN       6335338.0      13133400.0       1150337.0
# 16          0.0          NaN         44124.0         41355.0          4390.0
# 17          0.0          NaN         34539.0         53020.0          2328.0
# 18          0.0          NaN       2528757.0       6557735.0        897475.0
# 19          0.0          NaN        780011.0       1386969.0        204820.0
#
#     SP.POP.TOTL
# 0      313970.0
# 1     6788214.0
# 2     6652287.0
# 3     3075605.0
# 4   154670163.0
# 5    11124888.0
# 6       83636.0
# 7    10061515.0
# 8      117866.0
# 9      230939.0
# 10    2114020.0
# 11  240742196.0
# 12    4545550.0
# 13      61601.0
# 14    3747369.0
# 15   20619075.0
# 16      89869.0
# 17      89887.0
# 18    9983967.0
# 19    2371800.0

# %% [markdown]
# ## Exercise
#
# Kat wants to identify the countries that are conducive to start a business.  She thinks that it would suffice to look at the most recent metrics for the following:
# - Gross National Income (GNI)
# - Cost of business start-up procedures
# - Number of days required to start a business
# - Number of start-up procedures to register a business
# - GDP
# - GDP per capita
# - Business Regulatory Environment
# - Ease of doing business index (Only available in 2017)
#
# Write the data to a csv file.
#
# Hint - Start by matching up indicators that might have descriptions matching what Kat is looking for. e.g. <br>
# `showDF(seriesDim.filter("indicator_name like '%GNI%'").orderBy("indicator_code"), limitRows = 500)`

# %%
showDF(indicatorsData.filter("indicator_code like '%GDP%'").orderBy("indicator_code"), limitRows=2)
# Out:
#   wb_country_code     indicator_code  1960  1961  1962  1963  1964  1965  \
# 0             PRT  EG.GDP.PUSE.KO.PP   NaN   NaN   NaN   NaN   NaN   NaN
# 1             PRI  EG.GDP.PUSE.KO.PP   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1966  1967  ...       2008       2009      2010       2011       2012  \
# 0   NaN   NaN  ...  11.394297  11.486141  12.29841  12.375433  12.973981
# 1   NaN   NaN  ...        NaN        NaN       NaN        NaN        NaN
#
#         2013       2014       2015  2016  2017
# 0  13.557526  14.129503  13.854028   NaN   NaN
# 1        NaN        NaN        NaN   NaN   NaN
#
# [2 rows x 60 columns]

# %%
# Take need indicators

# This is the ease of buisness insicator
easeIndicator = indicatorsData \
    .select("wb_country_code", "indicator_code", "2017") \
    .filter(col('indicator_code').isin('IC.BUS.EASE.XQ')) \
    .withColumnRenamed("2017", "indicator_values")

# This is the collection of indicators for understanding country situation
usefulIndicators = indicatorsData \
    .select("wb_country_code", "indicator_code", "2016") \
    .filter(col('indicator_code').isin('NY.GNP.ATLS.CD', "IC.REG.COST.PC.ZS", 'NY.GDP.MKTP.KD', "NY.GDP.PCAP.KD")) \
    .withColumnRenamed("2016", "indicator_values") 

needInfo = easeIndicator.union(usefulIndicators)

showDF(needInfo.filter(col('indicator_values').isNotNull()))
# Out:
#    wb_country_code  indicator_code  indicator_values
# 0              AFG  IC.BUS.EASE.XQ             183.0
# 1              ALB  IC.BUS.EASE.XQ              65.0
# 2              DZA  IC.BUS.EASE.XQ             166.0
# 3              AGO  IC.BUS.EASE.XQ             175.0
# 4              ATG  IC.BUS.EASE.XQ             107.0
# 5              ARG  IC.BUS.EASE.XQ             117.0
# 6              ARM  IC.BUS.EASE.XQ              47.0
# 7              AUS  IC.BUS.EASE.XQ              14.0
# 8              AUT  IC.BUS.EASE.XQ              22.0
# 9              AZE  IC.BUS.EASE.XQ              57.0
# 10             BHS  IC.BUS.EASE.XQ             119.0
# 11             BHR  IC.BUS.EASE.XQ              66.0
# 12             BGD  IC.BUS.EASE.XQ             177.0
# 13             BRB  IC.BUS.EASE.XQ             132.0
# 14             BLR  IC.BUS.EASE.XQ              38.0
# 15             BEL  IC.BUS.EASE.XQ              52.0
# 16             BLZ  IC.BUS.EASE.XQ             121.0
# 17             BEN  IC.BUS.EASE.XQ             151.0
# 18             BTN  IC.BUS.EASE.XQ              75.0
# 19             BOL  IC.BUS.EASE.XQ             152.0

# %%
allBuisnessInfo = needInfo.join(countryDimFinal, needInfo.wb_country_code == countryDimFinal.wb_country_code,
                                'inner') \
    .select(countryDimFinal.country_iso_code,
            countryDimFinal.country_name,
            needInfo.indicator_code,
            needInfo.indicator_values) \
    .groupBy('country_iso_code', 'country_name').pivot('indicator_code').sum('indicator_values') \
    .withColumnRenamed('country_iso_code', 'Country ISO Code') \
    .withColumnRenamed('country_name', 'Country Name') \
    .withColumnRenamed('NY.GNP.ATLS.CD', 'GNI') \
    .withColumnRenamed('IC.REG.COST.PC.ZS', 'Startup Cost Pct of GNI') \
    .withColumnRenamed('NY.GDP.MKTP.KD', 'GDP') \
    .withColumnRenamed('NY.GDP.PCAP.KD', 'GDP Per Capita') \
    .withColumnRenamed('IC.BUS.EASE.XQ', 'Ease of business') \
    .withColumn('Startup Cost', (col('GNI') * col('Startup Cost Pct of GNI') / lit(100.0)).cast(DecimalType(38, 2))) \
    .filter(col('GNI') > 0) \
    .filter(col('Ease of business').isNotNull()) \
    .filter(col('Startup Cost').isNotNull()) \
    .orderBy(col('Ease of business').desc()) # First of all are countys which are better for buisness because
                                             # high GDP and GNI

showDF(allBuisnessInfo)
# Out:
#    Country ISO Code              Country Name  Ease of business  \
# 0                YE                     Yemen             186.0
# 1                CF  Central African Republic             184.0
# 2                AF               Afghanistan             183.0
# 3                CD           Dem. Rep. Congo             182.0
# 4                HT                     Haiti             181.0
# 5                TD                      Chad             180.0
# 6                CG                     Congo             179.0
# 7                TL               Timor-Leste             178.0
# 8                BD                Bangladesh             177.0
# 9                GW             Guinea-Bissau             176.0
# 10               AO                    Angola             175.0
# 11               GQ         Equatorial Guinea             173.0
# 12               LR                   Liberia             172.0
# 13               MM                   Myanmar             171.0
# 14               SD                     Sudan             170.0
# 15               ST     São Tomé and Principe             169.0
# 16               IQ                      Iraq             168.0
# 17               GA                     Gabon             167.0
# 18               DZ                   Algeria             166.0
# 19               SR                  Suriname             165.0
#
#     Startup Cost Pct of GNI           GDP  GDP Per Capita           GNI  \
# 0                      82.2  1.874809e+10      679.667360  2.877410e+10
# 1                     186.0  1.496561e+09      325.720292  1.722909e+09
# 2                      19.9  2.141361e+10      617.889972  1.997900e+10
# 3                      29.3  3.054732e+10      387.970757  3.626626e+10
# 4                     219.3  7.910618e+09      729.268442  8.488281e+09
# 5                     159.8  1.242411e+10      859.648572  1.036691e+10
# 6                      61.2  1.434239e+10     2798.066097  8.770007e+09
# 7                       0.5  1.192299e+09      939.801679  2.610847e+09
# 8                      15.6  1.677710e+11     1029.578212  2.162910e+11
# 9                      52.9  1.057415e+09      582.374006  1.084806e+09
# 10                     20.7  1.032280e+11     3582.647562  9.940413e+10
# 11                    102.7  1.499761e+10    12278.129140  8.766317e+09
# 12                     16.7  1.627047e+09      352.646078  1.720256e+09
# 13                     41.1  7.446983e+10     1408.140660  6.308586e+10
# 14                     30.5  7.614948e+10     1923.995322  8.489276e+10
# 15                     15.2  2.566618e+08     1283.886707  3.428457e+08
# 16                     51.9  2.118940e+11     5695.679143  2.016470e+11
# 17                     14.3  1.894547e+10     9569.454388  1.426983e+10
# 18                     11.1  1.960350e+11     4827.724251  1.713790e+11
# 19                    101.4  4.527380e+09     8108.236645  3.902912e+09
#
#        Startup Cost
# 0    23652311381.21
# 1     3204610057.38
# 2     3975821313.82
# 3    10626015309.22
# 4    18614799189.13
# 5    16566318880.13
# 6     5367244011.66
# 7       13054234.84
# 8    33741396000.00
# 9      573862287.24
# 10   20576654484.82
# 11    9003007118.42
# 12     287282764.02
# 13   25928287499.90
# 14   25892290957.29
# 15      52112545.69
# 16  104654793000.00
# 17    2040585155.18
# 18   19023069000.00
# 19    3957553221.26

# %%
allBuisnessInfo.coalesce(1).write.csv('../output/BusinessStartupData', mode='overwrite', header='true')
